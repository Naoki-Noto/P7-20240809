# %%
import pickle
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_max_pool
from torch_geometric.data import Batch
from torch_geometric.loader import DataLoader
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(30, 256)
        self.conv2 = GCNConv(256, 256)
        self.conv3 = GCNConv(256, 256)
        self.conv4 = GCNConv(256, 256)
        self.fc1 = nn.Linear(256, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = F.relu(x)
        x = global_max_pool(x, data.batch)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %%
def custom_collate(batch):
    data_list, target_list = zip(*batch)
    batch_data = Batch.from_data_list(data_list)
    batch_target = torch.stack(target_list)
    return batch_data, batch_target

# %%
torch.manual_seed(0)

target_data = "kappa2"
scaler = StandardScaler()
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
    
for d in ["AI+Human", "AI2+Human", "Random+Human"]:
    torch.manual_seed(0)
    print('Dataset : ', d)
    dataset = d

    with open(f'data_{dataset}/data_train_list.pkl', 'rb') as f:
        data_train_list = pickle.load(f)
    with open(f'data_{dataset}/data_val_list.pkl', 'rb') as f:
        data_val_list = pickle.load(f)
    with open(f'data_{dataset}/data_test_list.pkl', 'rb') as f:
        data_test_list = pickle.load(f)
    with open(f'data_{dataset}/target_train_{target_data}.pkl', 'rb') as f:
        target_train = pickle.load(f)
    with open(f'data_{dataset}/target_val_{target_data}.pkl', 'rb') as f:
        target_val = pickle.load(f)
    with open(f'data_{dataset}/target_test_{target_data}.pkl', 'rb') as f:
        target_test = pickle.load(f)
        
    target_train = scaler.fit_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_val = scaler.transform(np.array(target_val).reshape(-1, 1)).flatten()
    target_test = scaler.transform(np.array(target_test).reshape(-1, 1)).flatten()
    target_train = torch.tensor(target_train, dtype=torch.float32)
    target_val = torch.tensor(target_val, dtype=torch.float32)
    target_test = torch.tensor(target_test, dtype=torch.float32)

    train_loader = DataLoader(list(zip(data_train_list, target_train)), batch_size=128, collate_fn=custom_collate)
    val_loader = DataLoader(list(zip(data_val_list, target_val)), batch_size=128, collate_fn=custom_collate)
    test_loader = DataLoader(list(zip(data_test_list, target_test)), batch_size=128, collate_fn=custom_collate)

    model = Net().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping_patience = 30
    best_val_loss = float('inf')
    patience_counter = 0

    loss_train = []
    for epoch in range(100):
        model.train()
        for data, target in train_loader:
            data = data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            out = model(data)
            loss = criterion(out, target.view(-1, 1))
            loss.backward()
            optimizer.step()
            loss_train.append(loss.item())
        
        model.eval()
        val_loss = 0
        total_size = 0
        with torch.no_grad():
            for data, target in val_loader:
                data = data.to(device)
                target = target.to(device)
                out = model(data)
                loss = criterion(out, target.view(-1, 1))
                val_loss += loss.item() * data.size(0)
                total_size += data.size(0)
        val_loss /= total_size
        
        print(f'Epoch {epoch+1}, Validation Loss: {val_loss}')
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), f'data_{dataset}/model_{dataset}_sc.pth')
        else:
            patience_counter += 1
        if patience_counter >= early_stopping_patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
    
    model.load_state_dict(torch.load(f'data_{dataset}/model_{dataset}_sc.pth'))
    model.eval()
    
    pred_train = []
    for data, target in train_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_train.append(out.cpu().numpy())
    pred_train = np.concatenate(pred_train)

    pred_test = []
    for data, target in test_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_test.append(out.cpu().numpy())
    pred_test = np.concatenate(pred_test)

    pred_train = scaler.inverse_transform(pred_train)
    pred_test = scaler.inverse_transform(pred_test)
    target_train = scaler.inverse_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_test = scaler.inverse_transform(np.array(target_test).reshape(-1, 1)).flatten()

    print('R2 train:', metrics.r2_score(target_train, pred_train))
    print('R2 test:', metrics.r2_score(target_test, pred_test))
    
    n = 25
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(range(0, n+1), range(0, n+1), c='black')
    plt.scatter(target_test, pred_test, c='green', s=5)
    plt.xlim(0, n)
    plt.ylim(0, n)
    ax.set_aspect('equal', adjustable='box')
    plt.xlabel("calculation")
    plt.ylabel("prediction")
    plt.show()
    fig.savefig(f'data_{dataset}/source_sc.pdf')
    print('======================================================')
# Out:
# Dataset :  AI+Human
# Epoch 1, Validation Loss: 0.4377088547953053
# Epoch 2, Validation Loss: 0.2700667713318225
# Epoch 3, Validation Loss: 0.18194354489392536
# Epoch 4, Validation Loss: 0.1414573733843596
# Epoch 5, Validation Loss: 0.11809129612154858
# Epoch 6, Validation Loss: 0.09432223489728156
# Epoch 7, Validation Loss: 0.08514011664515231
# Epoch 8, Validation Loss: 0.08214543649809092
# Epoch 9, Validation Loss: 0.08649314891586973
# Epoch 10, Validation Loss: 0.07616925882023096
# Epoch 11, Validation Loss: 0.06258609063822479
# Epoch 12, Validation Loss: 0.05919774787303144
# Epoch 13, Validation Loss: 0.054520131517014805
# Epoch 14, Validation Loss: 0.05240997057427945
# Epoch 15, Validation Loss: 0.05399853071627543
# Epoch 16, Validation Loss: 0.04912296327659562
# Epoch 17, Validation Loss: 0.0460213385924653
# Epoch 18, Validation Loss: 0.044123917620397766
# Epoch 19, Validation Loss: 0.048358678379891495
# Epoch 20, Validation Loss: 0.04412575113996412
# Epoch 21, Validation Loss: 0.04048132268815346
# Epoch 22, Validation Loss: 0.038515869076302195
# Epoch 23, Validation Loss: 0.043003589471774184
# Epoch 24, Validation Loss: 0.03881045791523884
# Epoch 25, Validation Loss: 0.037966512004840317
# Epoch 26, Validation Loss: 0.03365283953465033
# Epoch 27, Validation Loss: 0.0335482810917547
# Epoch 28, Validation Loss: 0.033542548053431966
# Epoch 29, Validation Loss: 0.051118438016808536
# Epoch 30, Validation Loss: 0.03297611088475806
# Epoch 31, Validation Loss: 0.033398950363939986
# Epoch 32, Validation Loss: 0.032266476265668725
# Epoch 33, Validation Loss: 0.03151438979063152
# Epoch 34, Validation Loss: 0.030271972831778186
# Epoch 35, Validation Loss: 0.028162558238495086
# Epoch 36, Validation Loss: 0.02783651946199439
# Epoch 37, Validation Loss: 0.02900861305008559
# Epoch 38, Validation Loss: 0.029354102341586644
# Epoch 39, Validation Loss: 0.03158272420229609
# Epoch 40, Validation Loss: 0.035030555689236055
# Epoch 41, Validation Loss: 0.02739724406933947
# Epoch 42, Validation Loss: 0.02811189636425277
# Epoch 43, Validation Loss: 0.028934500098134166
# Epoch 44, Validation Loss: 0.02670288992515953
# Epoch 45, Validation Loss: 0.025360088678476667
# Epoch 46, Validation Loss: 0.02545501947029571
# Epoch 47, Validation Loss: 0.02504650873080266
# Epoch 48, Validation Loss: 0.025457091776887257
# Epoch 49, Validation Loss: 0.02500555256330012
# Epoch 50, Validation Loss: 0.024189574311855307
# Epoch 51, Validation Loss: 0.024715202750604674
# Epoch 52, Validation Loss: 0.02381139784319171
# Epoch 53, Validation Loss: 0.026236563459007062
# Epoch 54, Validation Loss: 0.02587978386342255
# Epoch 55, Validation Loss: 0.02484464305877686
# Epoch 56, Validation Loss: 0.02503818710506725
# Epoch 57, Validation Loss: 0.023202286296216523
# Epoch 58, Validation Loss: 0.025299300423207556
# Epoch 59, Validation Loss: 0.047698991428221184
# Epoch 60, Validation Loss: 0.028692731958198072
# Epoch 61, Validation Loss: 0.02440813024724916
# Epoch 62, Validation Loss: 0.023305713103546753
# Epoch 63, Validation Loss: 0.023093450657086553
# Epoch 64, Validation Loss: 0.02251805848951642
# Epoch 65, Validation Loss: 0.02176655823490924
# Epoch 66, Validation Loss: 0.022296285500170564
# Epoch 67, Validation Loss: 0.02200790201595457
# Epoch 68, Validation Loss: 0.02367666792650736
# Epoch 69, Validation Loss: 0.027904622356778323
# Epoch 70, Validation Loss: 0.021950896451196692
# Epoch 71, Validation Loss: 0.021286889892488055
# Epoch 72, Validation Loss: 0.023974602455279898
# Epoch 73, Validation Loss: 0.02231495279737305
# Epoch 74, Validation Loss: 0.023192890346163036
# Epoch 75, Validation Loss: 0.027234984015372696
# Epoch 76, Validation Loss: 0.023885416285311153
# Epoch 77, Validation Loss: 0.030298494243063946
# Epoch 78, Validation Loss: 0.02312158321714257
# Epoch 79, Validation Loss: 0.021797413536470862
# Epoch 80, Validation Loss: 0.02209919550927604
# Epoch 81, Validation Loss: 0.02130530641570397
# Epoch 82, Validation Loss: 0.021742572516692
# Epoch 83, Validation Loss: 0.02125232807933633
# Epoch 84, Validation Loss: 0.02052834437017813
# Epoch 85, Validation Loss: 0.02117630023295785
# Epoch 86, Validation Loss: 0.021825104773363604
# Epoch 87, Validation Loss: 0.020103753715721297
# Epoch 88, Validation Loss: 0.021989408928608237
# Epoch 89, Validation Loss: 0.021884220914677385
# Epoch 90, Validation Loss: 0.023868775525814106
# Epoch 91, Validation Loss: 0.041762188675276674
# Epoch 92, Validation Loss: 0.02031304713147666
# Epoch 93, Validation Loss: 0.01973094376478704
# Epoch 94, Validation Loss: 0.021470918652171347
# Epoch 95, Validation Loss: 0.022287795130868635
# Epoch 96, Validation Loss: 0.02172494346532468
# Epoch 97, Validation Loss: 0.021434297705075343
# Epoch 98, Validation Loss: 0.026043716203481494
# Epoch 99, Validation Loss: 0.027156386213032326
# Epoch 100, Validation Loss: 0.027110947918909684
# R2 train: 0.9914243817329407
# R2 test: 0.9812278747558594
# ======================================================
# Dataset :  AI2+Human
# Epoch 1, Validation Loss: 0.30368486523740074
# Epoch 2, Validation Loss: 0.19914092096238695
# Epoch 3, Validation Loss: 0.137557096150569
# Epoch 4, Validation Loss: 0.09903501933140392
# Epoch 5, Validation Loss: 0.0821228590611223
# Epoch 6, Validation Loss: 0.0721165198169951
# Epoch 7, Validation Loss: 0.059711863180775385
# Epoch 8, Validation Loss: 0.0533715517143429
# Epoch 9, Validation Loss: 0.048209605554444535
# Epoch 10, Validation Loss: 0.044070291790575686
# Epoch 11, Validation Loss: 0.04035222799222038
# Epoch 12, Validation Loss: 0.0391589790748324
# Epoch 13, Validation Loss: 0.04086962808279583
# Epoch 14, Validation Loss: 0.03876853713113981
# Epoch 15, Validation Loss: 0.042714040602127155
# Epoch 16, Validation Loss: 0.03709472070824673
# Epoch 17, Validation Loss: 0.039328596196983506
# Epoch 18, Validation Loss: 0.057086701107552776
# Epoch 19, Validation Loss: 0.03088869245091382
# Epoch 20, Validation Loss: 0.03345911895471947
# Epoch 21, Validation Loss: 0.033195743621063555
# Epoch 22, Validation Loss: 0.03023526649546507
# Epoch 23, Validation Loss: 0.030961118390021247
# Epoch 24, Validation Loss: 0.0239050744251688
# Epoch 25, Validation Loss: 0.04088506252338532
# Epoch 26, Validation Loss: 0.03750733447643019
# Epoch 27, Validation Loss: 0.03643575022551387
# Epoch 28, Validation Loss: 0.0369173972283054
# Epoch 29, Validation Loss: 0.02608259593844777
# Epoch 30, Validation Loss: 0.027947914537201905
# Epoch 31, Validation Loss: 0.027607779862163905
# Epoch 32, Validation Loss: 0.02691301444289767
# Epoch 33, Validation Loss: 0.025283622231364627
# Epoch 34, Validation Loss: 0.022414937278857017
# Epoch 35, Validation Loss: 0.022220780534513433
# Epoch 36, Validation Loss: 0.027603448942995854
# Epoch 37, Validation Loss: 0.03179972566981965
# Epoch 38, Validation Loss: 0.02983905334469578
# Epoch 39, Validation Loss: 0.040818040100518246
# Epoch 40, Validation Loss: 0.0268663661980905
# Epoch 41, Validation Loss: 0.01877081731562774
# Epoch 42, Validation Loss: 0.018104442747998536
# Epoch 43, Validation Loss: 0.02057642293228068
# Epoch 44, Validation Loss: 0.01756852029208407
# Epoch 45, Validation Loss: 0.01799504022736439
# Epoch 46, Validation Loss: 0.01777188407297179
# Epoch 47, Validation Loss: 0.01751443247873243
# Epoch 48, Validation Loss: 0.018533743178230935
# Epoch 49, Validation Loss: 0.018669179487278774
# Epoch 50, Validation Loss: 0.017862070492208677
# Epoch 51, Validation Loss: 0.016582759867708054
# Epoch 52, Validation Loss: 0.01719540109198057
# Epoch 53, Validation Loss: 0.01875998497006207
# Epoch 54, Validation Loss: 0.035775819321322753
# Epoch 55, Validation Loss: 0.01811767289951591
# Epoch 56, Validation Loss: 0.020248845952908205
# Epoch 57, Validation Loss: 0.020374807597348697
# Epoch 58, Validation Loss: 0.01704136635387939
# Epoch 59, Validation Loss: 0.029512095933089774
# Epoch 60, Validation Loss: 0.018707126575190823
# Epoch 61, Validation Loss: 0.01731622500264237
# Epoch 62, Validation Loss: 0.015636825630413152
# Epoch 63, Validation Loss: 0.01627382457334251
# Epoch 64, Validation Loss: 0.018596710482202593
# Epoch 65, Validation Loss: 0.016776471562543523
# Epoch 66, Validation Loss: 0.016631305938457182
# Epoch 67, Validation Loss: 0.01830003033045086
# Epoch 68, Validation Loss: 0.015149582698350683
# Epoch 69, Validation Loss: 0.014362019557502971
# Epoch 70, Validation Loss: 0.014343066273402618
# Epoch 71, Validation Loss: 0.013622409289710155
# Epoch 72, Validation Loss: 0.014117948581353762
# Epoch 73, Validation Loss: 0.01520027331800801
# Epoch 74, Validation Loss: 0.016064726875530063
# Epoch 75, Validation Loss: 0.014243476227077015
# Epoch 76, Validation Loss: 0.016086558617455615
# Epoch 77, Validation Loss: 0.014110848387928088
# Epoch 78, Validation Loss: 0.014213076978711213
# Epoch 79, Validation Loss: 0.014044986173430984
# Epoch 80, Validation Loss: 0.013870525065883241
# Epoch 81, Validation Loss: 0.014117971124008026
# Epoch 82, Validation Loss: 0.014737130447109526
# Epoch 83, Validation Loss: 0.013888855900315475
# Epoch 84, Validation Loss: 0.014131657237496216
# Epoch 85, Validation Loss: 0.015099417045395639
# Epoch 86, Validation Loss: 0.013501400246244041
# Epoch 87, Validation Loss: 0.0147493774917963
# Epoch 88, Validation Loss: 0.02103817176078493
# Epoch 89, Validation Loss: 0.022361830814767978
# Epoch 90, Validation Loss: 0.014595158815383128
# Epoch 91, Validation Loss: 0.018849938278944968
# Epoch 92, Validation Loss: 0.020432175454104386
# Epoch 93, Validation Loss: 0.01680630135219571
# Epoch 94, Validation Loss: 0.014703751331216075
# Epoch 95, Validation Loss: 0.013203200244040383
# Epoch 96, Validation Loss: 0.013094864360448481
# Epoch 97, Validation Loss: 0.012368521934242031
# Epoch 98, Validation Loss: 0.012584025521071159
# Epoch 99, Validation Loss: 0.013218909285228184
# Epoch 100, Validation Loss: 0.012594764836982289
# R2 train: 0.9942985773086548
# R2 test: 0.9873817563056946
# ======================================================
# Dataset :  Random+Human
# Epoch 1, Validation Loss: 0.3886248985976787
# Epoch 2, Validation Loss: 0.23678751749659518
# Epoch 3, Validation Loss: 0.16478656523988153
# Epoch 4, Validation Loss: 0.1271484148675046
# Epoch 5, Validation Loss: 0.099090442845773
# Epoch 6, Validation Loss: 0.0823251091062412
# Epoch 7, Validation Loss: 0.07123869091871696
# Epoch 8, Validation Loss: 0.06061131869365571
# Epoch 9, Validation Loss: 0.057693119259894246
# Epoch 10, Validation Loss: 0.06051367054270058
# Epoch 11, Validation Loss: 0.056134556056312235
# Epoch 12, Validation Loss: 0.05480363228527369
# Epoch 13, Validation Loss: 0.05039451561556571
# Epoch 14, Validation Loss: 0.047282737754313055
# Epoch 15, Validation Loss: 0.04245974119152198
# Epoch 16, Validation Loss: 0.04124226892650484
# Epoch 17, Validation Loss: 0.041313668274999826
# Epoch 18, Validation Loss: 0.037915989194848634
# Epoch 19, Validation Loss: 0.037740985890287695
# Epoch 20, Validation Loss: 0.03525316517742258
# Epoch 21, Validation Loss: 0.03648090142151628
# Epoch 22, Validation Loss: 0.033019340703595725
# Epoch 23, Validation Loss: 0.03466299185090207
# Epoch 24, Validation Loss: 0.03761273162906773
# Epoch 25, Validation Loss: 0.055731678299549864
# Epoch 26, Validation Loss: 0.03281137753420643
# Epoch 27, Validation Loss: 0.02999636702373278
# Epoch 28, Validation Loss: 0.028522370788128415
# Epoch 29, Validation Loss: 0.02925251661318355
# Epoch 30, Validation Loss: 0.029094444061844593
# Epoch 31, Validation Loss: 0.029238918004271513
# Epoch 32, Validation Loss: 0.027845163087976774
# Epoch 33, Validation Loss: 0.027816825710747527
# Epoch 34, Validation Loss: 0.028398987039836406
# Epoch 35, Validation Loss: 0.026420161689054398
# Epoch 36, Validation Loss: 0.028112061224995114
# Epoch 37, Validation Loss: 0.027045614817477977
# Epoch 38, Validation Loss: 0.02819869964533877
# Epoch 39, Validation Loss: 0.026314883727312707
# Epoch 40, Validation Loss: 0.025683659029691705
# Epoch 41, Validation Loss: 0.025667822077419643
# Epoch 42, Validation Loss: 0.0260229746673963
# Epoch 43, Validation Loss: 0.026111648902579516
# Epoch 44, Validation Loss: 0.027138714253027437
# Epoch 45, Validation Loss: 0.024862441769345725
# Epoch 46, Validation Loss: 0.024193465050032815
# Epoch 47, Validation Loss: 0.02418698113055912
# Epoch 48, Validation Loss: 0.024834390934520747
# Epoch 49, Validation Loss: 0.024677516774847644
# Epoch 50, Validation Loss: 0.024633900346169132
# Epoch 51, Validation Loss: 0.02517817126946743
# Epoch 52, Validation Loss: 0.03100566321145003
# Epoch 53, Validation Loss: 0.024933760298974535
# Epoch 54, Validation Loss: 0.024247641074041027
# Epoch 55, Validation Loss: 0.028455904982904647
# Epoch 56, Validation Loss: 0.02425823669149935
# Epoch 57, Validation Loss: 0.023114664690969858
# Epoch 58, Validation Loss: 0.022222454790421828
# Epoch 59, Validation Loss: 0.02224896180809498
# Epoch 60, Validation Loss: 0.021201405229969314
# Epoch 61, Validation Loss: 0.021275763460002633
# Epoch 62, Validation Loss: 0.021517262559145458
# Epoch 63, Validation Loss: 0.023352164894478687
# Epoch 64, Validation Loss: 0.02177222893062172
# Epoch 65, Validation Loss: 0.021855851591059818
# Epoch 66, Validation Loss: 0.02192062426597842
# Epoch 67, Validation Loss: 0.022576280777269763
# Epoch 68, Validation Loss: 0.02204782156283151
# Epoch 69, Validation Loss: 0.02214896027877334
# Epoch 70, Validation Loss: 0.02554126730790647
# Epoch 71, Validation Loss: 0.025057333283618588
# Epoch 72, Validation Loss: 0.022428657038520997
# Epoch 73, Validation Loss: 0.02403293526091888
# Epoch 74, Validation Loss: 0.019929465375919424
# Epoch 75, Validation Loss: 0.020702209744255132
# Epoch 76, Validation Loss: 0.021578669110692818
# Epoch 77, Validation Loss: 0.02215948852433127
# Epoch 78, Validation Loss: 0.022478343706036394
# Epoch 79, Validation Loss: 0.02313507089276091
# Epoch 80, Validation Loss: 0.02333317178818487
# Epoch 81, Validation Loss: 0.022796859307437387
# Epoch 82, Validation Loss: 0.021638405032004218
# Epoch 83, Validation Loss: 0.020652599651941585
# Epoch 84, Validation Loss: 0.022294334483670995
# Epoch 85, Validation Loss: 0.021336862612928657
# Epoch 86, Validation Loss: 0.023131949441772697
# Epoch 87, Validation Loss: 0.020629301300254588
# Epoch 88, Validation Loss: 0.025212695170494428
# Epoch 89, Validation Loss: 0.023845399893716823
# Epoch 90, Validation Loss: 0.023100037413871736
# Epoch 91, Validation Loss: 0.027233522436906465
# Epoch 92, Validation Loss: 0.03576820555042681
# Epoch 93, Validation Loss: 0.04595439628896701
# Epoch 94, Validation Loss: 0.03770689762591401
# Epoch 95, Validation Loss: 0.021598370161781948
# Epoch 96, Validation Loss: 0.020471217988183434
# Epoch 97, Validation Loss: 0.02021393871070842
# Epoch 98, Validation Loss: 0.019697800323396675
# Epoch 99, Validation Loss: 0.019441574103656906
# Epoch 100, Validation Loss: 0.02045340609229102
# R2 train: 0.9923115968704224
# R2 test: 0.9796563982963562
# ======================================================
