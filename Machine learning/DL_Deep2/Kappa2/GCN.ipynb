# %%
import pickle
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_max_pool
from torch_geometric.data import Batch
from torch_geometric.loader import DataLoader
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(30, 256)
        self.conv2 = GCNConv(256, 256)
        self.conv3 = GCNConv(256, 256)
        self.conv4 = GCNConv(256, 256)
        self.fc1 = nn.Linear(256, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = F.relu(x)
        x = global_max_pool(x, data.batch)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %%
def custom_collate(batch):
    data_list, target_list = zip(*batch)
    batch_data = Batch.from_data_list(data_list)
    batch_target = torch.stack(target_list)
    return batch_data, batch_target

# %%
torch.manual_seed(0)

target_data = "kappa2"
scaler = StandardScaler()
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
    
for d in ["AI", "AI2", "Random", "Human"]:
    torch.manual_seed(0)
    print('Dataset : ', d)
    dataset = d

    with open(f'data_{dataset}/data_train_list.pkl', 'rb') as f:
        data_train_list = pickle.load(f)
    with open(f'data_{dataset}/data_val_list.pkl', 'rb') as f:
        data_val_list = pickle.load(f)
    with open(f'data_{dataset}/data_test_list.pkl', 'rb') as f:
        data_test_list = pickle.load(f)
    with open(f'data_{dataset}/target_train_{target_data}.pkl', 'rb') as f:
        target_train = pickle.load(f)
    with open(f'data_{dataset}/target_val_{target_data}.pkl', 'rb') as f:
        target_val = pickle.load(f)
    with open(f'data_{dataset}/target_test_{target_data}.pkl', 'rb') as f:
        target_test = pickle.load(f)
        
    target_train = scaler.fit_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_val = scaler.transform(np.array(target_val).reshape(-1, 1)).flatten()
    target_test = scaler.transform(np.array(target_test).reshape(-1, 1)).flatten()
    target_train = torch.tensor(target_train, dtype=torch.float32)
    target_val = torch.tensor(target_val, dtype=torch.float32)
    target_test = torch.tensor(target_test, dtype=torch.float32)

    train_loader = DataLoader(list(zip(data_train_list, target_train)), batch_size=128, collate_fn=custom_collate)
    val_loader = DataLoader(list(zip(data_val_list, target_val)), batch_size=128, collate_fn=custom_collate)
    test_loader = DataLoader(list(zip(data_test_list, target_test)), batch_size=128, collate_fn=custom_collate)

    model = Net().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping_patience = 30
    best_val_loss = float('inf')
    patience_counter = 0

    loss_train = []
    for epoch in range(100):
        model.train()
        for data, target in train_loader:
            data = data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            out = model(data)
            loss = criterion(out, target.view(-1, 1))
            loss.backward()
            optimizer.step()
            loss_train.append(loss.item())
        
        model.eval()
        val_loss = 0
        total_size = 0
        with torch.no_grad():
            for data, target in val_loader:
                data = data.to(device)
                target = target.to(device)
                out = model(data)
                loss = criterion(out, target.view(-1, 1))
                val_loss += loss.item() * data.size(0)
                total_size += data.size(0)
        val_loss /= total_size
        
        print(f'Epoch {epoch+1}, Validation Loss: {val_loss}')
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), f'data_{dataset}/model_{dataset}_sc.pth')
        else:
            patience_counter += 1
        if patience_counter >= early_stopping_patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
    
    model.load_state_dict(torch.load(f'data_{dataset}/model_{dataset}_sc.pth'))
    model.eval()
    
    pred_train = []
    for data, target in train_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_train.append(out.cpu().numpy())
    pred_train = np.concatenate(pred_train)

    pred_test = []
    for data, target in test_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_test.append(out.cpu().numpy())
    pred_test = np.concatenate(pred_test)

    pred_train = scaler.inverse_transform(pred_train)
    pred_test = scaler.inverse_transform(pred_test)
    target_train = scaler.inverse_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_test = scaler.inverse_transform(np.array(target_test).reshape(-1, 1)).flatten()

    print('R2 train:', metrics.r2_score(target_train, pred_train))
    print('R2 test:', metrics.r2_score(target_test, pred_test))
    
    n = 25
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(range(0, n+1), range(0, n+1), c='black')
    plt.scatter(target_test, pred_test, c='green', s=5)
    plt.xlim(0, n)
    plt.ylim(0, n)
    ax.set_aspect('equal', adjustable='box')
    plt.xlabel("calculation")
    plt.ylabel("prediction")
    plt.show()
    fig.savefig(f'data_{dataset}/source_sc.pdf')
    print('======================================================')
# Out:
# Dataset :  AI
# Epoch 1, Validation Loss: 0.33166828663832865
# Epoch 2, Validation Loss: 0.2345698289700566
# Epoch 3, Validation Loss: 0.21501137196784406
# Epoch 4, Validation Loss: 0.19649924203836341
# Epoch 5, Validation Loss: 0.1174405388259372
# Epoch 6, Validation Loss: 0.13567211870196919
# Epoch 7, Validation Loss: 0.11084667673912647
# Epoch 8, Validation Loss: 0.11605530849808154
# Epoch 9, Validation Loss: 0.1011326329079519
# Epoch 10, Validation Loss: 0.08517725739463104
# Epoch 11, Validation Loss: 0.07943039702165998
# Epoch 12, Validation Loss: 0.07543014485328377
# Epoch 13, Validation Loss: 0.0685345956472302
# Epoch 14, Validation Loss: 0.06382343180264306
# Epoch 15, Validation Loss: 0.06964475939408267
# Epoch 16, Validation Loss: 0.06201789479348981
# Epoch 17, Validation Loss: 0.06449235098584181
# Epoch 18, Validation Loss: 0.06261863674280203
# Epoch 19, Validation Loss: 0.058423881754816255
# Epoch 20, Validation Loss: 0.05924461760334325
# Epoch 21, Validation Loss: 0.059117244828772474
# Epoch 22, Validation Loss: 0.058467106310027266
# Epoch 23, Validation Loss: 0.05469019244790814
# Epoch 24, Validation Loss: 0.05469000000651661
# Epoch 25, Validation Loss: 0.05244602617624491
# Epoch 26, Validation Loss: 0.05268210282073146
# Epoch 27, Validation Loss: 0.051385348401403574
# Epoch 28, Validation Loss: 0.05158852389496276
# Epoch 29, Validation Loss: 0.05875985853587316
# Epoch 30, Validation Loss: 0.05037758401685407
# Epoch 31, Validation Loss: 0.04965932164167032
# Epoch 32, Validation Loss: 0.04859409316306134
# Epoch 33, Validation Loss: 0.05061414378701904
# Epoch 34, Validation Loss: 0.050077964229085295
# Epoch 35, Validation Loss: 0.05426275940024582
# Epoch 36, Validation Loss: 0.055564152090728715
# Epoch 37, Validation Loss: 0.05307404889953615
# Epoch 38, Validation Loss: 0.04752303248702191
# Epoch 39, Validation Loss: 0.04557468189561527
# Epoch 40, Validation Loss: 0.045227306671801235
# Epoch 41, Validation Loss: 0.04271850704482299
# Epoch 42, Validation Loss: 0.044861426087198
# Epoch 43, Validation Loss: 0.04399626508453356
# Epoch 44, Validation Loss: 0.04450355078995105
# Epoch 45, Validation Loss: 0.04535710491080424
# Epoch 46, Validation Loss: 0.04187700704535053
# Epoch 47, Validation Loss: 0.04209680377480974
# Epoch 48, Validation Loss: 0.04148130423168198
# Epoch 49, Validation Loss: 0.04240393602217324
# Epoch 50, Validation Loss: 0.042070194346943424
# Epoch 51, Validation Loss: 0.042026044923064027
# Epoch 52, Validation Loss: 0.04423148108721087
# Epoch 53, Validation Loss: 0.051750994705362006
# Epoch 54, Validation Loss: 0.04921980926064519
# Epoch 55, Validation Loss: 0.041130876172767485
# Epoch 56, Validation Loss: 0.04064431835331951
# Epoch 57, Validation Loss: 0.055330164094694365
# Epoch 58, Validation Loss: 0.06511511104065161
# Epoch 59, Validation Loss: 0.04470045431786966
# Epoch 60, Validation Loss: 0.042954075418266895
# Epoch 61, Validation Loss: 0.03892756052069696
# Epoch 62, Validation Loss: 0.03926812178471982
# Epoch 63, Validation Loss: 0.03891710392147088
# Epoch 64, Validation Loss: 0.03898969859684349
# Epoch 65, Validation Loss: 0.03826350543440064
# Epoch 66, Validation Loss: 0.03784597944501254
# Epoch 67, Validation Loss: 0.038285916922865273
# Epoch 68, Validation Loss: 0.03724258340213805
# Epoch 69, Validation Loss: 0.037871899781923214
# Epoch 70, Validation Loss: 0.03862796660826515
# Epoch 71, Validation Loss: 0.03729578080573853
# Epoch 72, Validation Loss: 0.037962622857885674
# Epoch 73, Validation Loss: 0.042979112509273595
# Epoch 74, Validation Loss: 0.046892890783880446
# Epoch 75, Validation Loss: 0.040423663650387104
# Epoch 76, Validation Loss: 0.040881833272371305
# Epoch 77, Validation Loss: 0.03824743034421293
# Epoch 78, Validation Loss: 0.04421349804198521
# Epoch 79, Validation Loss: 0.03867058363222315
# Epoch 80, Validation Loss: 0.04205653070115957
# Epoch 81, Validation Loss: 0.04323292350049306
# Epoch 82, Validation Loss: 0.05859996161260762
# Epoch 83, Validation Loss: 0.04403353364916037
# Epoch 84, Validation Loss: 0.04192811517581635
# Epoch 85, Validation Loss: 0.04102252515289553
# Epoch 86, Validation Loss: 0.040443488358407755
# Epoch 87, Validation Loss: 0.04065556465503668
# Epoch 88, Validation Loss: 0.0427002873020333
# Epoch 89, Validation Loss: 0.037662752081418505
# Epoch 90, Validation Loss: 0.03583371258134945
# Epoch 91, Validation Loss: 0.03776408081052846
# Epoch 92, Validation Loss: 0.03751696816341516
# Epoch 93, Validation Loss: 0.037493256312059325
# Epoch 94, Validation Loss: 0.03595298741865293
# Epoch 95, Validation Loss: 0.03716998363451229
# Epoch 96, Validation Loss: 0.035700082808732984
# Epoch 97, Validation Loss: 0.0478926235631983
# Epoch 98, Validation Loss: 0.061958184325455634
# Epoch 99, Validation Loss: 0.03663374902783719
# Epoch 100, Validation Loss: 0.045268145638486385
# R2 train: 0.9834781885147095
# R2 test: 0.9629473090171814
# ======================================================
# Dataset :  AI2
# Epoch 1, Validation Loss: 0.29808642807733465
# Epoch 2, Validation Loss: 0.19697074147859533
# Epoch 3, Validation Loss: 0.166327512648585
# Epoch 4, Validation Loss: 0.1355533193437893
# Epoch 5, Validation Loss: 0.1426172608541137
# Epoch 6, Validation Loss: 0.11094311261903757
# Epoch 7, Validation Loss: 0.0803060690904173
# Epoch 8, Validation Loss: 0.07311773785113668
# Epoch 9, Validation Loss: 0.0800904030426754
# Epoch 10, Validation Loss: 0.08013878379234159
# Epoch 11, Validation Loss: 0.06398588859386783
# Epoch 12, Validation Loss: 0.0577874240902155
# Epoch 13, Validation Loss: 0.05465173048431247
# Epoch 14, Validation Loss: 0.05238127444242065
# Epoch 15, Validation Loss: 0.05383710492913523
# Epoch 16, Validation Loss: 0.049657053203231695
# Epoch 17, Validation Loss: 0.0503793044083535
# Epoch 18, Validation Loss: 0.04641125376754627
# Epoch 19, Validation Loss: 0.04612843239378724
# Epoch 20, Validation Loss: 0.04307344416960496
# Epoch 21, Validation Loss: 0.04576361292240951
# Epoch 22, Validation Loss: 0.041626332094456354
# Epoch 23, Validation Loss: 0.04343260091674037
# Epoch 24, Validation Loss: 0.039652538214739914
# Epoch 25, Validation Loss: 0.04028062159025291
# Epoch 26, Validation Loss: 0.04172004602202491
# Epoch 27, Validation Loss: 0.03880122522581736
# Epoch 28, Validation Loss: 0.04035200594781689
# Epoch 29, Validation Loss: 0.045556231834938975
# Epoch 30, Validation Loss: 0.03794054835889948
# Epoch 31, Validation Loss: 0.03790681697280459
# Epoch 32, Validation Loss: 0.035652815326348425
# Epoch 33, Validation Loss: 0.037858687506171496
# Epoch 34, Validation Loss: 0.031983414817913176
# Epoch 35, Validation Loss: 0.03205382094146786
# Epoch 36, Validation Loss: 0.030583814260404827
# Epoch 37, Validation Loss: 0.029696423970111654
# Epoch 38, Validation Loss: 0.041284345071801884
# Epoch 39, Validation Loss: 0.04099044385213565
# Epoch 40, Validation Loss: 0.03631589120306644
# Epoch 41, Validation Loss: 0.03567073368974438
# Epoch 42, Validation Loss: 0.038429936673040684
# Epoch 43, Validation Loss: 0.037848237184431685
# Epoch 44, Validation Loss: 0.03633560829278667
# Epoch 45, Validation Loss: 0.03796490237318444
# Epoch 46, Validation Loss: 0.0364039627298694
# Epoch 47, Validation Loss: 0.029518218042351267
# Epoch 48, Validation Loss: 0.027758922814919124
# Epoch 49, Validation Loss: 0.027877114065060236
# Epoch 50, Validation Loss: 0.02788312519563251
# Epoch 51, Validation Loss: 0.02879061333311983
# Epoch 52, Validation Loss: 0.029086986327829797
# Epoch 53, Validation Loss: 0.033389821835071755
# Epoch 54, Validation Loss: 0.0378326807201101
# Epoch 55, Validation Loss: 0.03486406083727774
# Epoch 56, Validation Loss: 0.0269391477992378
# Epoch 57, Validation Loss: 0.02470599534506171
# Epoch 58, Validation Loss: 0.02794226649467502
# Epoch 59, Validation Loss: 0.024984271590845243
# Epoch 60, Validation Loss: 0.026722512776702376
# Epoch 61, Validation Loss: 0.023380327127427752
# Epoch 62, Validation Loss: 0.030434832377100922
# Epoch 63, Validation Loss: 0.028636201247069067
# Epoch 64, Validation Loss: 0.023249706821102077
# Epoch 65, Validation Loss: 0.021343726639706392
# Epoch 66, Validation Loss: 0.022864464702393148
# Epoch 67, Validation Loss: 0.024773555077342205
# Epoch 68, Validation Loss: 0.024247310700588883
# Epoch 69, Validation Loss: 0.033508717034208046
# Epoch 70, Validation Loss: 0.04012975686629038
# Epoch 71, Validation Loss: 0.04101535776406959
# Epoch 72, Validation Loss: 0.022075982751792005
# Epoch 73, Validation Loss: 0.029546618378572254
# Epoch 74, Validation Loss: 0.024749050727221108
# Epoch 75, Validation Loss: 0.02722975399209963
# Epoch 76, Validation Loss: 0.02439469311949163
# Epoch 77, Validation Loss: 0.020883436259789844
# Epoch 78, Validation Loss: 0.023642275650119032
# Epoch 79, Validation Loss: 0.02224068928140948
# Epoch 80, Validation Loss: 0.020300657317541625
# Epoch 81, Validation Loss: 0.02060560757948874
# Epoch 82, Validation Loss: 0.020724321986998712
# Epoch 83, Validation Loss: 0.02093850038738359
# Epoch 84, Validation Loss: 0.020521938357912956
# Epoch 85, Validation Loss: 0.020628862611656654
# Epoch 86, Validation Loss: 0.0219898372673775
# Epoch 87, Validation Loss: 0.024598373071404434
# Epoch 88, Validation Loss: 0.026707774784015124
# Epoch 89, Validation Loss: 0.022778958187633692
# Epoch 90, Validation Loss: 0.018999994729333454
# Epoch 91, Validation Loss: 0.02437807603634582
# Epoch 92, Validation Loss: 0.02226957445230586
# Epoch 93, Validation Loss: 0.026387785522817356
# Epoch 94, Validation Loss: 0.031105958403775856
# Epoch 95, Validation Loss: 0.021054795063278144
# Epoch 96, Validation Loss: 0.020186163257566336
# Epoch 97, Validation Loss: 0.018578545625794075
# Epoch 98, Validation Loss: 0.01901581793322193
# Epoch 99, Validation Loss: 0.0189919823895329
# Epoch 100, Validation Loss: 0.019229891987188722
# R2 train: 0.9891776442527771
# R2 test: 0.9790326356887817
# ======================================================
# Dataset :  Random
# Epoch 1, Validation Loss: 0.276233911775748
# Epoch 2, Validation Loss: 0.1844948673204594
# Epoch 3, Validation Loss: 0.1460676012422381
# Epoch 4, Validation Loss: 0.11603332418939756
# Epoch 5, Validation Loss: 0.10198656200106619
# Epoch 6, Validation Loss: 0.09213765645975004
# Epoch 7, Validation Loss: 0.09216745706195562
# Epoch 8, Validation Loss: 0.08511869248789851
# Epoch 9, Validation Loss: 0.08052371501464146
# Epoch 10, Validation Loss: 0.08054128110626074
# Epoch 11, Validation Loss: 0.08193608915389859
# Epoch 12, Validation Loss: 0.07990737524089232
# Epoch 13, Validation Loss: 0.07584520141148561
# Epoch 14, Validation Loss: 0.06509627136064926
# Epoch 15, Validation Loss: 0.06575567315806946
# Epoch 16, Validation Loss: 0.07073973738640253
# Epoch 17, Validation Loss: 0.08416072320950885
# Epoch 18, Validation Loss: 0.06204813439185593
# Epoch 19, Validation Loss: 0.06809918047864294
# Epoch 20, Validation Loss: 0.062411535206091835
# Epoch 21, Validation Loss: 0.062197753926727904
# Epoch 22, Validation Loss: 0.05666681640790342
# Epoch 23, Validation Loss: 0.055714804947784566
# Epoch 24, Validation Loss: 0.05313810418920251
# Epoch 25, Validation Loss: 0.05289119271984296
# Epoch 26, Validation Loss: 0.05108889041982031
# Epoch 27, Validation Loss: 0.050177329630925194
# Epoch 28, Validation Loss: 0.0490082829014958
# Epoch 29, Validation Loss: 0.04915781263197861
# Epoch 30, Validation Loss: 0.04912087203192029
# Epoch 31, Validation Loss: 0.04779303237418555
# Epoch 32, Validation Loss: 0.04744222333882947
# Epoch 33, Validation Loss: 0.04692316677114795
# Epoch 34, Validation Loss: 0.047748910205753774
# Epoch 35, Validation Loss: 0.047941254258696664
# Epoch 36, Validation Loss: 0.047956948253059656
# Epoch 37, Validation Loss: 0.0478632080559499
# Epoch 38, Validation Loss: 0.04735923079806168
# Epoch 39, Validation Loss: 0.05110853778053749
# Epoch 40, Validation Loss: 0.049271592025575454
# Epoch 41, Validation Loss: 0.04725264050385841
# Epoch 42, Validation Loss: 0.04662964932236087
# Epoch 43, Validation Loss: 0.04604343424158169
# Epoch 44, Validation Loss: 0.04685032814526231
# Epoch 45, Validation Loss: 0.049381653161527074
# Epoch 46, Validation Loss: 0.049082668014476624
# Epoch 47, Validation Loss: 0.04664342314367249
# Epoch 48, Validation Loss: 0.046241531376559404
# Epoch 49, Validation Loss: 0.04605311048109293
# Epoch 50, Validation Loss: 0.04477914022012391
# Epoch 51, Validation Loss: 0.04739747038902801
# Epoch 52, Validation Loss: 0.0452791638889643
# Epoch 53, Validation Loss: 0.043468303174226966
# Epoch 54, Validation Loss: 0.042243680056978775
# Epoch 55, Validation Loss: 0.042246939962752646
# Epoch 56, Validation Loss: 0.041934069855170446
# Epoch 57, Validation Loss: 0.043923059518457735
# Epoch 58, Validation Loss: 0.04507795242181839
# Epoch 59, Validation Loss: 0.04432428128297725
# Epoch 60, Validation Loss: 0.04403117568841833
# Epoch 61, Validation Loss: 0.04427363040826647
# Epoch 62, Validation Loss: 0.04303576829974926
# Epoch 63, Validation Loss: 0.04276277271844312
# Epoch 64, Validation Loss: 0.04157700485063126
# Epoch 65, Validation Loss: 0.042011277103991655
# Epoch 66, Validation Loss: 0.04083613616373104
# Epoch 67, Validation Loss: 0.039883750444252006
# Epoch 68, Validation Loss: 0.040192224449204166
# Epoch 69, Validation Loss: 0.039724152731284525
# Epoch 70, Validation Loss: 0.043061033900797026
# Epoch 71, Validation Loss: 0.04696435101209994
# Epoch 72, Validation Loss: 0.046937903928309356
# Epoch 73, Validation Loss: 0.04194821647155931
# Epoch 74, Validation Loss: 0.04206910086511388
# Epoch 75, Validation Loss: 0.04921330378500017
# Epoch 76, Validation Loss: 0.039124265287016846
# Epoch 77, Validation Loss: 0.04470154774987063
# Epoch 78, Validation Loss: 0.0788480285346489
# Epoch 79, Validation Loss: 0.06852084241142455
# Epoch 80, Validation Loss: 0.04915134634999604
# Epoch 81, Validation Loss: 0.047539342693162505
# Epoch 82, Validation Loss: 0.04498454839290836
# Epoch 83, Validation Loss: 0.04485804693544009
# Epoch 84, Validation Loss: 0.03940832078986377
# Epoch 85, Validation Loss: 0.03943508929430402
# Epoch 86, Validation Loss: 0.03919779734345604
# Epoch 87, Validation Loss: 0.03820481822915437
# Epoch 88, Validation Loss: 0.03837006763287898
# Epoch 89, Validation Loss: 0.03775046555815339
# Epoch 90, Validation Loss: 0.03674179203371039
# Epoch 91, Validation Loss: 0.037887189859283646
# Epoch 92, Validation Loss: 0.0386831771557293
# Epoch 93, Validation Loss: 0.04753147899849623
# Epoch 94, Validation Loss: 0.042775974526055804
# Epoch 95, Validation Loss: 0.03804487414946398
# Epoch 96, Validation Loss: 0.055936981633087066
# Epoch 97, Validation Loss: 0.0787553882372154
# Epoch 98, Validation Loss: 0.04886567157629557
# Epoch 99, Validation Loss: 0.04169681445638675
# Epoch 100, Validation Loss: 0.04434393729292845
# R2 train: 0.9836982488632202
# R2 test: 0.9666711091995239
# ======================================================
# Dataset :  Human
# Epoch 1, Validation Loss: 0.3533037228953772
# Epoch 2, Validation Loss: 0.2876396993155538
# Epoch 3, Validation Loss: 0.1541246750374037
# Epoch 4, Validation Loss: 0.09438468482488234
# Epoch 5, Validation Loss: 0.08293905933454276
# Epoch 6, Validation Loss: 0.07005883698998261
# Epoch 7, Validation Loss: 0.06183385277802628
# Epoch 8, Validation Loss: 0.05277064344498359
# Epoch 9, Validation Loss: 0.040533747342477694
# Epoch 10, Validation Loss: 0.03833160634421846
# Epoch 11, Validation Loss: 0.03285805106446035
# Epoch 12, Validation Loss: 0.02906234929811884
# Epoch 13, Validation Loss: 0.025035691290666677
# Epoch 14, Validation Loss: 0.02063120124890218
# Epoch 15, Validation Loss: 0.021031387962959173
# Epoch 16, Validation Loss: 0.020450032836904476
# Epoch 17, Validation Loss: 0.018146813697830232
# Epoch 18, Validation Loss: 0.023606052727309375
# Epoch 19, Validation Loss: 0.023071000143182106
# Epoch 20, Validation Loss: 0.01727075075454254
# Epoch 21, Validation Loss: 0.017631302852667414
# Epoch 22, Validation Loss: 0.011010031673341126
# Epoch 23, Validation Loss: 0.011093660196400781
# Epoch 24, Validation Loss: 0.016498700948870394
# Epoch 25, Validation Loss: 0.013332621327514855
# Epoch 26, Validation Loss: 0.015396888900202148
# Epoch 27, Validation Loss: 0.013114575957134823
# Epoch 28, Validation Loss: 0.012947782361923255
# Epoch 29, Validation Loss: 0.016892013175308997
# Epoch 30, Validation Loss: 0.010061117990712395
# Epoch 31, Validation Loss: 0.011058481065058506
# Epoch 32, Validation Loss: 0.009237324766281951
# Epoch 33, Validation Loss: 0.007215440266618501
# Epoch 34, Validation Loss: 0.015649215037337797
# Epoch 35, Validation Loss: 0.012531684865048487
# Epoch 36, Validation Loss: 0.008645666888930075
# Epoch 37, Validation Loss: 0.007353908866838631
# Epoch 38, Validation Loss: 0.008290476621318113
# Epoch 39, Validation Loss: 0.00721885321573545
# Epoch 40, Validation Loss: 0.005616282506711905
# Epoch 41, Validation Loss: 0.005096752695690969
# Epoch 42, Validation Loss: 0.004996513803549968
# Epoch 43, Validation Loss: 0.005292445726735572
# Epoch 44, Validation Loss: 0.005417001345555396
# Epoch 45, Validation Loss: 0.0048751038413680815
# Epoch 46, Validation Loss: 0.005652632323452708
# Epoch 47, Validation Loss: 0.00514248937348366
# Epoch 48, Validation Loss: 0.0044428955989557276
# Epoch 49, Validation Loss: 0.06395378591355355
# Epoch 50, Validation Loss: 0.017716081897236516
# Epoch 51, Validation Loss: 0.009130829196212489
# Epoch 52, Validation Loss: 0.008609424789765913
# Epoch 53, Validation Loss: 0.0071321664242085464
# Epoch 54, Validation Loss: 0.006506745996192547
# Epoch 55, Validation Loss: 0.006261597384405457
# Epoch 56, Validation Loss: 0.005360098153594516
# Epoch 57, Validation Loss: 0.004269394543536936
# Epoch 58, Validation Loss: 0.004513953007317833
# Epoch 59, Validation Loss: 0.0043959398521916
# Epoch 60, Validation Loss: 0.003980914288685486
# Epoch 61, Validation Loss: 0.0037666445810905225
# Epoch 62, Validation Loss: 0.0037249560253943084
# Epoch 63, Validation Loss: 0.0035679499333299033
# Epoch 64, Validation Loss: 0.0034897538082837827
# Epoch 65, Validation Loss: 0.0035406673224441564
# Epoch 66, Validation Loss: 0.0035106901597024634
# Epoch 67, Validation Loss: 0.003438508373221339
# Epoch 68, Validation Loss: 0.003500023573232173
# Epoch 69, Validation Loss: 0.004636847779511036
# Epoch 70, Validation Loss: 0.006071474291620871
# Epoch 71, Validation Loss: 0.006186927707373199
# Epoch 72, Validation Loss: 0.0035504327255957667
# Epoch 73, Validation Loss: 0.0037693861248835445
# Epoch 74, Validation Loss: 0.009706342087709263
# Epoch 75, Validation Loss: 0.004585087927751452
# Epoch 76, Validation Loss: 0.0038810717860801747
# Epoch 77, Validation Loss: 0.0036247655595653973
# Epoch 78, Validation Loss: 0.003121889934771229
# Epoch 79, Validation Loss: 0.0028815501728072074
# Epoch 80, Validation Loss: 0.002807279057666714
# Epoch 81, Validation Loss: 0.0027070360255501704
# Epoch 82, Validation Loss: 0.0025904396114103923
# Epoch 83, Validation Loss: 0.0025524025470073618
# Epoch 84, Validation Loss: 0.0024587598551483493
# Epoch 85, Validation Loss: 0.0024192681302987943
# Epoch 86, Validation Loss: 0.0026817104914850873
# Epoch 87, Validation Loss: 0.0030761016760559334
# Epoch 88, Validation Loss: 0.00400514386926334
# Epoch 89, Validation Loss: 0.004070671846873363
# Epoch 90, Validation Loss: 0.00340108982579228
# Epoch 91, Validation Loss: 0.004850302801308683
# Epoch 92, Validation Loss: 0.0034780902163430794
# Epoch 93, Validation Loss: 0.002437512510919883
# Epoch 94, Validation Loss: 0.0023264445399903554
# Epoch 95, Validation Loss: 0.002248616677566275
# Epoch 96, Validation Loss: 0.0025679176988050623
# Epoch 97, Validation Loss: 0.16945361554475186
# Epoch 98, Validation Loss: 0.0236669265942754
# Epoch 99, Validation Loss: 0.009359156400354876
# Epoch 100, Validation Loss: 0.0052578963508033314
# R2 train: 0.9986107349395752
# R2 test: 0.9981485605239868
# ======================================================
