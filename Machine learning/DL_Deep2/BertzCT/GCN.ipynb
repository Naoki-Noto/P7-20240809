# %%
import pickle
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_max_pool
from torch_geometric.data import Batch
from torch_geometric.loader import DataLoader
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(30, 256)
        self.conv2 = GCNConv(256, 256)
        self.conv3 = GCNConv(256, 256)
        self.conv4 = GCNConv(256, 256)
        self.fc1 = nn.Linear(256, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = F.relu(x)
        x = global_max_pool(x, data.batch)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %%
def custom_collate(batch):
    data_list, target_list = zip(*batch)
    batch_data = Batch.from_data_list(data_list)
    batch_target = torch.stack(target_list)
    return batch_data, batch_target

# %%
torch.manual_seed(0)

target_data = "bertzct"
scaler = StandardScaler()
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
    
for d in ["AI", "AI2", "Random", "Human"]:
    torch.manual_seed(0)
    print('Dataset : ', d)
    dataset = d

    with open(f'data_{dataset}/data_train_list.pkl', 'rb') as f:
        data_train_list = pickle.load(f)
    with open(f'data_{dataset}/data_val_list.pkl', 'rb') as f:
        data_val_list = pickle.load(f)
    with open(f'data_{dataset}/data_test_list.pkl', 'rb') as f:
        data_test_list = pickle.load(f)
    with open(f'data_{dataset}/target_train_{target_data}.pkl', 'rb') as f:
        target_train = pickle.load(f)
    with open(f'data_{dataset}/target_val_{target_data}.pkl', 'rb') as f:
        target_val = pickle.load(f)
    with open(f'data_{dataset}/target_test_{target_data}.pkl', 'rb') as f:
        target_test = pickle.load(f)
        
    target_train = scaler.fit_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_val = scaler.transform(np.array(target_val).reshape(-1, 1)).flatten()
    target_test = scaler.transform(np.array(target_test).reshape(-1, 1)).flatten()
    target_train = torch.tensor(target_train, dtype=torch.float32)
    target_val = torch.tensor(target_val, dtype=torch.float32)
    target_test = torch.tensor(target_test, dtype=torch.float32)

    train_loader = DataLoader(list(zip(data_train_list, target_train)), batch_size=128, collate_fn=custom_collate)
    val_loader = DataLoader(list(zip(data_val_list, target_val)), batch_size=128, collate_fn=custom_collate)
    test_loader = DataLoader(list(zip(data_test_list, target_test)), batch_size=128, collate_fn=custom_collate)

    model = Net().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping_patience = 30
    best_val_loss = float('inf')
    patience_counter = 0

    loss_train = []
    for epoch in range(100):
        model.train()
        for data, target in train_loader:
            data = data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            out = model(data)
            loss = criterion(out, target.view(-1, 1))
            loss.backward()
            optimizer.step()
            loss_train.append(loss.item())
        
        model.eval()
        val_loss = 0
        total_size = 0
        with torch.no_grad():
            for data, target in val_loader:
                data = data.to(device)
                target = target.to(device)
                out = model(data)
                loss = criterion(out, target.view(-1, 1))
                val_loss += loss.item() * data.size(0)
                total_size += data.size(0)
        val_loss /= total_size
        
        print(f'Epoch {epoch+1}, Validation Loss: {val_loss}')
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), f'data_{dataset}/model_{dataset}_sc.pth')
        else:
            patience_counter += 1
        if patience_counter >= early_stopping_patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
    
    model.load_state_dict(torch.load(f'data_{dataset}/model_{dataset}_sc.pth'))
    model.eval()
    
    pred_train = []
    for data, target in train_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_train.append(out.cpu().numpy())
    pred_train = np.concatenate(pred_train)

    pred_test = []
    for data, target in test_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_test.append(out.cpu().numpy())
    pred_test = np.concatenate(pred_test)

    pred_train = scaler.inverse_transform(pred_train)
    pred_test = scaler.inverse_transform(pred_test)
    target_train = scaler.inverse_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_test = scaler.inverse_transform(np.array(target_test).reshape(-1, 1)).flatten()

    print('R2 train:', metrics.r2_score(target_train, pred_train))
    print('R2 test:', metrics.r2_score(target_test, pred_test))
    
    n = 6000
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(range(0, n+1), range(0, n+1), c='black')
    plt.scatter(target_test, pred_test, c='green', s=5)
    plt.xlim(0, n)
    plt.ylim(0, n)
    ax.set_aspect('equal', adjustable='box')
    plt.xlabel("calculation")
    plt.ylabel("prediction")
    plt.show()
    fig.savefig(f'data_{dataset}/source_sc.pdf')
    print('======================================================')
# Out:
# Dataset :  AI
# Epoch 1, Validation Loss: 0.4321611927265242
# Epoch 2, Validation Loss: 0.3097251917899698
# Epoch 3, Validation Loss: 0.2908105677659676
# Epoch 4, Validation Loss: 0.14285958774702434
# Epoch 5, Validation Loss: 0.11603166675653566
# Epoch 6, Validation Loss: 0.12619828413406925
# Epoch 7, Validation Loss: 0.09520331993082157
# Epoch 8, Validation Loss: 0.0810684762855514
# Epoch 9, Validation Loss: 0.07637195803481323
# Epoch 10, Validation Loss: 0.07138066182007013
# Epoch 11, Validation Loss: 0.07036651522624014
# Epoch 12, Validation Loss: 0.06638956866512338
# Epoch 13, Validation Loss: 0.06344883474149002
# Epoch 14, Validation Loss: 0.0648815511855173
# Epoch 15, Validation Loss: 0.056104435403885974
# Epoch 16, Validation Loss: 0.0904198119726596
# Epoch 17, Validation Loss: 0.06422551391093419
# Epoch 18, Validation Loss: 0.05392516982880729
# Epoch 19, Validation Loss: 0.0641525023117063
# Epoch 20, Validation Loss: 0.06260036841751557
# Epoch 21, Validation Loss: 0.05897834897312949
# Epoch 22, Validation Loss: 0.05495224719857519
# Epoch 23, Validation Loss: 0.05050161319214517
# Epoch 24, Validation Loss: 0.04767376613567836
# Epoch 25, Validation Loss: 0.045872885776612714
# Epoch 26, Validation Loss: 0.044177827301050555
# Epoch 27, Validation Loss: 0.043169637560291955
# Epoch 28, Validation Loss: 0.045063527498658974
# Epoch 29, Validation Loss: 0.04351725766836185
# Epoch 30, Validation Loss: 0.04270631779047414
# Epoch 31, Validation Loss: 0.04162023426524827
# Epoch 32, Validation Loss: 0.041228238496319396
# Epoch 33, Validation Loss: 0.040525992376812335
# Epoch 34, Validation Loss: 0.04035279332049168
# Epoch 35, Validation Loss: 0.04151903337272446
# Epoch 36, Validation Loss: 0.04339434812973751
# Epoch 37, Validation Loss: 0.03991765646748513
# Epoch 38, Validation Loss: 0.040784905339490495
# Epoch 39, Validation Loss: 0.038909404639219894
# Epoch 40, Validation Loss: 0.04009443365959748
# Epoch 41, Validation Loss: 0.04804171582786357
# Epoch 42, Validation Loss: 0.06828425058943481
# Epoch 43, Validation Loss: 0.04051290880258739
# Epoch 44, Validation Loss: 0.041118139817850355
# Epoch 45, Validation Loss: 0.04053074752285417
# Epoch 46, Validation Loss: 0.040600367438780906
# Epoch 47, Validation Loss: 0.04068292356257151
# Epoch 48, Validation Loss: 0.05366832763932638
# Epoch 49, Validation Loss: 0.04539644555184304
# Epoch 50, Validation Loss: 0.04091209630031296
# Epoch 51, Validation Loss: 0.04004744296767255
# Epoch 52, Validation Loss: 0.03936210044857832
# Epoch 53, Validation Loss: 0.040878151245131306
# Epoch 54, Validation Loss: 0.04440359953535389
# Epoch 55, Validation Loss: 0.03886151933128323
# Epoch 56, Validation Loss: 0.04020887288334564
# Epoch 57, Validation Loss: 0.04180399905837282
# Epoch 58, Validation Loss: 0.04652889205771666
# Epoch 59, Validation Loss: 0.04306894347599557
# Epoch 60, Validation Loss: 0.06450227029288588
# Epoch 61, Validation Loss: 0.039094585893098284
# Epoch 62, Validation Loss: 0.037482220498298274
# Epoch 63, Validation Loss: 0.038044126018252605
# Epoch 64, Validation Loss: 0.04320896271173483
# Epoch 65, Validation Loss: 0.05484253061480674
# Epoch 66, Validation Loss: 0.03774423998795319
# Epoch 67, Validation Loss: 0.03902609668836289
# Epoch 68, Validation Loss: 0.04489905929870819
# Epoch 69, Validation Loss: 0.045808341370536784
# Epoch 70, Validation Loss: 0.04221771281294671
# Epoch 71, Validation Loss: 0.04025088001130845
# Epoch 72, Validation Loss: 0.040390903514703445
# Epoch 73, Validation Loss: 0.04046983192699945
# Epoch 74, Validation Loss: 0.03607730089732658
# Epoch 75, Validation Loss: 0.03381266525083909
# Epoch 76, Validation Loss: 0.03300335052667759
# Epoch 77, Validation Loss: 0.03225534410750154
# Epoch 78, Validation Loss: 0.031902213354849177
# Epoch 79, Validation Loss: 0.03306189881822231
# Epoch 80, Validation Loss: 0.03340505058811757
# Epoch 81, Validation Loss: 0.036531642239506286
# Epoch 82, Validation Loss: 0.03491896399037661
# Epoch 83, Validation Loss: 0.03373063961939021
# Epoch 84, Validation Loss: 0.034342348229305014
# Epoch 85, Validation Loss: 0.03397260994942193
# Epoch 86, Validation Loss: 0.03569647897147678
# Epoch 87, Validation Loss: 0.03418526695619589
# Epoch 88, Validation Loss: 0.040398720596603335
# Epoch 89, Validation Loss: 0.03424618679331088
# Epoch 90, Validation Loss: 0.031678890063560707
# Epoch 91, Validation Loss: 0.03155288649220729
# Epoch 92, Validation Loss: 0.03122144870728592
# Epoch 93, Validation Loss: 0.030495534658600814
# Epoch 94, Validation Loss: 0.031379328697904496
# Epoch 95, Validation Loss: 0.03233648223051634
# Epoch 96, Validation Loss: 0.032646077591530695
# Epoch 97, Validation Loss: 0.03558657208563862
# Epoch 98, Validation Loss: 0.05357528515054195
# Epoch 99, Validation Loss: 0.04840140311492091
# Epoch 100, Validation Loss: 0.07778294755584425
# R2 train: 0.9866263270378113
# R2 test: 0.9679610133171082
# ======================================================
# Dataset :  AI2
# Epoch 1, Validation Loss: 0.3341097164392363
# Epoch 2, Validation Loss: 0.2681549836046026
# Epoch 3, Validation Loss: 0.15568506365671247
# Epoch 4, Validation Loss: 0.1258348650998857
# Epoch 5, Validation Loss: 0.11454122189708142
# Epoch 6, Validation Loss: 0.12228653122331114
# Epoch 7, Validation Loss: 0.11224454276623012
# Epoch 8, Validation Loss: 0.08422021568698797
# Epoch 9, Validation Loss: 0.13661369284203806
# Epoch 10, Validation Loss: 0.10950164792684039
# Epoch 11, Validation Loss: 0.13503472946303835
# Epoch 12, Validation Loss: 0.1511775127540272
# Epoch 13, Validation Loss: 0.13725867269194325
# Epoch 14, Validation Loss: 0.06608845415316297
# Epoch 15, Validation Loss: 0.05847398422347764
# Epoch 16, Validation Loss: 0.07861463528611858
# Epoch 17, Validation Loss: 0.07820132718501094
# Epoch 18, Validation Loss: 0.0527745895652569
# Epoch 19, Validation Loss: 0.051491514747506836
# Epoch 20, Validation Loss: 0.05000053475428095
# Epoch 21, Validation Loss: 0.05110412473764562
# Epoch 22, Validation Loss: 0.050113584487792795
# Epoch 23, Validation Loss: 0.0467093885243882
# Epoch 24, Validation Loss: 0.05096756701875321
# Epoch 25, Validation Loss: 0.052579178700091246
# Epoch 26, Validation Loss: 0.04781233018520391
# Epoch 27, Validation Loss: 0.047276552785430685
# Epoch 28, Validation Loss: 0.040750555787199355
# Epoch 29, Validation Loss: 0.04414248349772357
# Epoch 30, Validation Loss: 0.046880711416915126
# Epoch 31, Validation Loss: 0.04041614185855916
# Epoch 32, Validation Loss: 0.043765208209501326
# Epoch 33, Validation Loss: 0.04331907630716602
# Epoch 34, Validation Loss: 0.04013045815070036
# Epoch 35, Validation Loss: 0.03801636240521112
# Epoch 36, Validation Loss: 0.03468858352530219
# Epoch 37, Validation Loss: 0.03453010296057554
# Epoch 38, Validation Loss: 0.03926496690626575
# Epoch 39, Validation Loss: 0.04809956526891106
# Epoch 40, Validation Loss: 0.05432836546889533
# Epoch 41, Validation Loss: 0.04358136476441656
# Epoch 42, Validation Loss: 0.04550294622988953
# Epoch 43, Validation Loss: 0.04201171236218981
# Epoch 44, Validation Loss: 0.034160353398605105
# Epoch 45, Validation Loss: 0.05499587408104705
# Epoch 46, Validation Loss: 0.06128850163211114
# Epoch 47, Validation Loss: 0.053145199344038024
# Epoch 48, Validation Loss: 0.06404690262149085
# Epoch 49, Validation Loss: 0.056303399757139605
# Epoch 50, Validation Loss: 0.056965402063572874
# Epoch 51, Validation Loss: 0.059035351113697364
# Epoch 52, Validation Loss: 0.06085347842558981
# Epoch 53, Validation Loss: 0.05850863902575337
# Epoch 54, Validation Loss: 0.050278823720500104
# Epoch 55, Validation Loss: 0.04870844220808736
# Epoch 56, Validation Loss: 0.039666639685576204
# Epoch 57, Validation Loss: 0.03350623319809619
# Epoch 58, Validation Loss: 0.02977596434638894
# Epoch 59, Validation Loss: 0.030236844747953448
# Epoch 60, Validation Loss: 0.032267913422571265
# Epoch 61, Validation Loss: 0.02944504468239969
# Epoch 62, Validation Loss: 0.032638836545184575
# Epoch 63, Validation Loss: 0.029483639948037065
# Epoch 64, Validation Loss: 0.038907262136671644
# Epoch 65, Validation Loss: 0.028800460571458374
# Epoch 66, Validation Loss: 0.03847383579526097
# Epoch 67, Validation Loss: 0.049732397119777436
# Epoch 68, Validation Loss: 0.041418220705100976
# Epoch 69, Validation Loss: 0.04415946271692767
# Epoch 70, Validation Loss: 0.03947271135767568
# Epoch 71, Validation Loss: 0.03528125099730446
# Epoch 72, Validation Loss: 0.03198050932277483
# Epoch 73, Validation Loss: 0.03512392363780114
# Epoch 74, Validation Loss: 0.05245530970361235
# Epoch 75, Validation Loss: 0.04982585134172458
# Epoch 76, Validation Loss: 0.03712106691198054
# Epoch 77, Validation Loss: 0.0317455394763367
# Epoch 78, Validation Loss: 0.05258600684616096
# Epoch 79, Validation Loss: 0.02925114056819996
# Epoch 80, Validation Loss: 0.029549114379593986
# Epoch 81, Validation Loss: 0.06073087043111625
# Epoch 82, Validation Loss: 0.04200774487685462
# Epoch 83, Validation Loss: 0.038174347526250985
# Epoch 84, Validation Loss: 0.03665981262452077
# Epoch 85, Validation Loss: 0.05796119878851086
# Epoch 86, Validation Loss: 0.031637113961522446
# Epoch 87, Validation Loss: 0.030406338962007545
# Epoch 88, Validation Loss: 0.026477491517393776
# Epoch 89, Validation Loss: 0.030602839145857468
# Epoch 90, Validation Loss: 0.03493442125526072
# Epoch 91, Validation Loss: 0.03275094151623139
# Epoch 92, Validation Loss: 0.024453503294422804
# Epoch 93, Validation Loss: 0.022754337356791915
# Epoch 94, Validation Loss: 0.02233460580624274
# Epoch 95, Validation Loss: 0.02265017051748673
# Epoch 96, Validation Loss: 0.02226531698660515
# Epoch 97, Validation Loss: 0.02149952305578921
# Epoch 98, Validation Loss: 0.02239075682565043
# Epoch 99, Validation Loss: 0.020809458101631047
# Epoch 100, Validation Loss: 0.02142363696926662
# R2 train: 0.9889797568321228
# R2 test: 0.9752721190452576
# ======================================================
# Dataset :  Random
# Epoch 1, Validation Loss: 0.3409611050531121
# Epoch 2, Validation Loss: 0.2945737892787346
# Epoch 3, Validation Loss: 0.15028820680056654
# Epoch 4, Validation Loss: 0.1377987265329566
# Epoch 5, Validation Loss: 0.11887611654600447
# Epoch 6, Validation Loss: 0.0977335811035009
# Epoch 7, Validation Loss: 0.10102115631707632
# Epoch 8, Validation Loss: 0.08769339433456401
# Epoch 9, Validation Loss: 0.07717318320756572
# Epoch 10, Validation Loss: 0.0731053931654567
# Epoch 11, Validation Loss: 0.06929420751907744
# Epoch 12, Validation Loss: 0.06761767516167402
# Epoch 13, Validation Loss: 0.08692331029462319
# Epoch 14, Validation Loss: 0.08076478584170552
# Epoch 15, Validation Loss: 0.06565067038147765
# Epoch 16, Validation Loss: 0.06440569525746502
# Epoch 17, Validation Loss: 0.060639416359710624
# Epoch 18, Validation Loss: 0.059466198832184666
# Epoch 19, Validation Loss: 0.059815568313976816
# Epoch 20, Validation Loss: 0.05846553518896578
# Epoch 21, Validation Loss: 0.06183123069755418
# Epoch 22, Validation Loss: 0.057844742689681365
# Epoch 23, Validation Loss: 0.05355522637981908
# Epoch 24, Validation Loss: 0.05432237135712766
# Epoch 25, Validation Loss: 0.053579379168199014
# Epoch 26, Validation Loss: 0.05333478539192961
# Epoch 27, Validation Loss: 0.0530241042460929
# Epoch 28, Validation Loss: 0.0632926697932693
# Epoch 29, Validation Loss: 0.06682029505508845
# Epoch 30, Validation Loss: 0.07089651977899614
# Epoch 31, Validation Loss: 0.07225476159431281
# Epoch 32, Validation Loss: 0.07597586478595955
# Epoch 33, Validation Loss: 0.08312363986881935
# Epoch 34, Validation Loss: 0.11108504788726675
# Epoch 35, Validation Loss: 0.0965239395491863
# Epoch 36, Validation Loss: 0.05895055412778143
# Epoch 37, Validation Loss: 0.04945329276271933
# Epoch 38, Validation Loss: 0.047194355981768146
# Epoch 39, Validation Loss: 0.046346700461500016
# Epoch 40, Validation Loss: 0.048278848490680835
# Epoch 41, Validation Loss: 0.04407968806211368
# Epoch 42, Validation Loss: 0.044251270644207356
# Epoch 43, Validation Loss: 0.04193099615655917
# Epoch 44, Validation Loss: 0.0410760624700298
# Epoch 45, Validation Loss: 0.04212949339611705
# Epoch 46, Validation Loss: 0.04278187197589435
# Epoch 47, Validation Loss: 0.044286225546294966
# Epoch 48, Validation Loss: 0.045327174468727825
# Epoch 49, Validation Loss: 0.044634373865331554
# Epoch 50, Validation Loss: 0.04443212417455407
# Epoch 51, Validation Loss: 0.04556841796013183
# Epoch 52, Validation Loss: 0.03888251097614223
# Epoch 53, Validation Loss: 0.042192538812763705
# Epoch 54, Validation Loss: 0.04208931877800798
# Epoch 55, Validation Loss: 0.046631389545444955
# Epoch 56, Validation Loss: 0.08183747154475692
# Epoch 57, Validation Loss: 0.06315983378543809
# Epoch 58, Validation Loss: 0.05350371358320553
# Epoch 59, Validation Loss: 0.049896565975507776
# Epoch 60, Validation Loss: 0.04726387624758008
# Epoch 61, Validation Loss: 0.049636535803118
# Epoch 62, Validation Loss: 0.05262591123041287
# Epoch 63, Validation Loss: 0.06068601358424332
# Epoch 64, Validation Loss: 0.053783176642834454
# Epoch 65, Validation Loss: 0.0483231941237598
# Epoch 66, Validation Loss: 0.04165820088691209
# Epoch 67, Validation Loss: 0.03942470076781128
# Epoch 68, Validation Loss: 0.03971561961212969
# Epoch 69, Validation Loss: 0.03934226587809328
# Epoch 70, Validation Loss: 0.04070010796505992
# Epoch 71, Validation Loss: 0.042001927282558825
# Epoch 72, Validation Loss: 0.039707812418112505
# Epoch 73, Validation Loss: 0.039535296031877346
# Epoch 74, Validation Loss: 0.05601914154320738
# Epoch 75, Validation Loss: 0.05857043133459239
# Epoch 76, Validation Loss: 0.09551858924315551
# Epoch 77, Validation Loss: 0.0793513391147226
# Epoch 78, Validation Loss: 0.05432920584188145
# Epoch 79, Validation Loss: 0.04576795058304487
# Epoch 80, Validation Loss: 0.03852459672355216
# Epoch 81, Validation Loss: 0.05236520079286812
# Epoch 82, Validation Loss: 0.09405226041562482
# Epoch 83, Validation Loss: 0.07860074119573578
# Epoch 84, Validation Loss: 0.07437738847563845
# Epoch 85, Validation Loss: 0.0657998697366155
# Epoch 86, Validation Loss: 0.06114624854764938
# Epoch 87, Validation Loss: 0.05369342336931542
# Epoch 88, Validation Loss: 0.05030426859792076
# Epoch 89, Validation Loss: 0.045804231890084965
# Epoch 90, Validation Loss: 0.043118553675813236
# Epoch 91, Validation Loss: 0.04184343512468867
# Epoch 92, Validation Loss: 0.03948452425449812
# Epoch 93, Validation Loss: 0.036650081183416616
# Epoch 94, Validation Loss: 0.041790186650600344
# Epoch 95, Validation Loss: 0.039043224926292655
# Epoch 96, Validation Loss: 0.0387669121690304
# Epoch 97, Validation Loss: 0.04204419944396556
# Epoch 98, Validation Loss: 0.09250218550001627
# Epoch 99, Validation Loss: 0.09112799940473347
# Epoch 100, Validation Loss: 0.03969079332176813
# R2 train: 0.9851512312889099
# R2 test: 0.9688981175422668
# ======================================================
# Dataset :  Human
# Epoch 1, Validation Loss: 0.3656754172193343
# Epoch 2, Validation Loss: 0.5006346679644338
# Epoch 3, Validation Loss: 0.25241564653830195
# Epoch 4, Validation Loss: 0.2162220497970057
# Epoch 5, Validation Loss: 0.0997363902885931
# Epoch 6, Validation Loss: 0.06340721997967491
# Epoch 7, Validation Loss: 0.057970129034008194
# Epoch 8, Validation Loss: 0.040649207402065735
# Epoch 9, Validation Loss: 0.03324198056004215
# Epoch 10, Validation Loss: 0.02895663159004195
# Epoch 11, Validation Loss: 0.023123072499765578
# Epoch 12, Validation Loss: 0.019654936031960394
# Epoch 13, Validation Loss: 0.017246990123435002
# Epoch 14, Validation Loss: 0.015623936349013039
# Epoch 15, Validation Loss: 0.014418903782541315
# Epoch 16, Validation Loss: 0.012948012192480962
# Epoch 17, Validation Loss: 0.011819935215905892
# Epoch 18, Validation Loss: 0.010489014446824914
# Epoch 19, Validation Loss: 0.011946708203158149
# Epoch 20, Validation Loss: 0.010074758408534674
# Epoch 21, Validation Loss: 0.009419691436770372
# Epoch 22, Validation Loss: 0.011134310342624954
# Epoch 23, Validation Loss: 0.008950875409721797
# Epoch 24, Validation Loss: 0.0086801781611898
# Epoch 25, Validation Loss: 0.01130660289069094
# Epoch 26, Validation Loss: 0.009323034668440028
# Epoch 27, Validation Loss: 0.008499627074806688
# Epoch 28, Validation Loss: 0.008670041938390138
# Epoch 29, Validation Loss: 0.01748181208020174
# Epoch 30, Validation Loss: 0.008692178139515387
# Epoch 31, Validation Loss: 0.008437184928643883
# Epoch 32, Validation Loss: 0.006906390293325683
# Epoch 33, Validation Loss: 0.006970496346966225
# Epoch 34, Validation Loss: 0.007024689719933006
# Epoch 35, Validation Loss: 0.006533294826638021
# Epoch 36, Validation Loss: 0.010097046532955099
# Epoch 37, Validation Loss: 0.009720548430043382
# Epoch 38, Validation Loss: 0.005776127923313679
# Epoch 39, Validation Loss: 0.010098038774063825
# Epoch 40, Validation Loss: 0.009112793863754633
# Epoch 41, Validation Loss: 0.007388477442660184
# Epoch 42, Validation Loss: 0.009449346230101902
# Epoch 43, Validation Loss: 0.005799185596488577
# Epoch 44, Validation Loss: 0.07473526707606436
# Epoch 45, Validation Loss: 0.024370037990941094
# Epoch 46, Validation Loss: 0.00751745635173072
# Epoch 47, Validation Loss: 0.005890400775092655
# Epoch 48, Validation Loss: 0.004636464467888702
# Epoch 49, Validation Loss: 0.0036573750126078254
# Epoch 50, Validation Loss: 0.0034794295261514896
# Epoch 51, Validation Loss: 0.0032760225951738403
# Epoch 52, Validation Loss: 0.0031754873468179882
# Epoch 53, Validation Loss: 0.002801156965966842
# Epoch 54, Validation Loss: 0.0029442508353899654
# Epoch 55, Validation Loss: 0.003522170167616257
# Epoch 56, Validation Loss: 0.0027680821294755525
# Epoch 57, Validation Loss: 0.0024670480225477973
# Epoch 58, Validation Loss: 0.003001709837154328
# Epoch 59, Validation Loss: 0.0025583585418962156
# Epoch 60, Validation Loss: 0.002625336500778384
# Epoch 61, Validation Loss: 0.0045074942839081105
# Epoch 62, Validation Loss: 0.002725044531128561
# Epoch 63, Validation Loss: 0.005716983441363502
# Epoch 64, Validation Loss: 0.002811951115733315
# Epoch 65, Validation Loss: 0.0031687463213860407
# Epoch 66, Validation Loss: 0.002743096742542539
# Epoch 67, Validation Loss: 0.002609038385219057
# Epoch 68, Validation Loss: 0.0023762615270576347
# Epoch 69, Validation Loss: 0.002308585320711916
# Epoch 70, Validation Loss: 0.003896922674849854
# Epoch 71, Validation Loss: 0.00259902970167284
# Epoch 72, Validation Loss: 0.015353875680565319
# Epoch 73, Validation Loss: 0.004888884384691154
# Epoch 74, Validation Loss: 0.0035566171183417125
# Epoch 75, Validation Loss: 0.002771304102603677
# Epoch 76, Validation Loss: 0.0024173306556822334
# Epoch 77, Validation Loss: 0.0019451766792633722
# Epoch 78, Validation Loss: 0.001650344161457946
# Epoch 79, Validation Loss: 0.0015133491072016102
# Epoch 80, Validation Loss: 0.001443694270455403
# Epoch 81, Validation Loss: 0.0014282055825283041
# Epoch 82, Validation Loss: 0.001848738615925428
# Epoch 83, Validation Loss: 0.0019467450579270565
# Epoch 84, Validation Loss: 0.0014376901764764083
# Epoch 85, Validation Loss: 0.0016047745619381245
# Epoch 86, Validation Loss: 0.0015616647995292346
# Epoch 87, Validation Loss: 0.0014978342597018407
# Epoch 88, Validation Loss: 0.0014320653076231834
# Epoch 89, Validation Loss: 0.0013478833480396364
# Epoch 90, Validation Loss: 0.0012394222811500876
# Epoch 91, Validation Loss: 0.0027818776025320085
# Epoch 92, Validation Loss: 0.002246105670661294
# Epoch 93, Validation Loss: 0.00155972173774123
# Epoch 94, Validation Loss: 0.0015476586472823368
# Epoch 95, Validation Loss: 0.0020327926038663695
# Epoch 96, Validation Loss: 0.0014772704164570836
# Epoch 97, Validation Loss: 0.0017032068994595733
# Epoch 98, Validation Loss: 0.0022032903511050627
# Epoch 99, Validation Loss: 0.0014861940988621005
# Epoch 100, Validation Loss: 0.0017063740886867167
# R2 train: 0.9991322755813599
# R2 test: 0.9985774159431458
# ======================================================
