# %%
import pickle
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_max_pool
from torch_geometric.data import Batch
from torch_geometric.loader import DataLoader
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(30, 256)
        self.conv2 = GCNConv(256, 256)
        self.conv3 = GCNConv(256, 256)
        self.conv4 = GCNConv(256, 256)
        self.fc1 = nn.Linear(256, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.conv4(x, edge_index)
        x = F.relu(x)
        x = global_max_pool(x, data.batch)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        return x

# %%
def custom_collate(batch):
    data_list, target_list = zip(*batch)
    batch_data = Batch.from_data_list(data_list)
    batch_target = torch.stack(target_list)
    return batch_data, batch_target

# %%
torch.manual_seed(0)

target_data = "bertzct"
scaler = StandardScaler()
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
    
for d in ["AI+Human", "AI2+Human", "Random+Human"]:
    torch.manual_seed(0)
    print('Dataset : ', d)
    dataset = d

    with open(f'data_{dataset}/data_train_list.pkl', 'rb') as f:
        data_train_list = pickle.load(f)
    with open(f'data_{dataset}/data_val_list.pkl', 'rb') as f:
        data_val_list = pickle.load(f)
    with open(f'data_{dataset}/data_test_list.pkl', 'rb') as f:
        data_test_list = pickle.load(f)
    with open(f'data_{dataset}/target_train_{target_data}.pkl', 'rb') as f:
        target_train = pickle.load(f)
    with open(f'data_{dataset}/target_val_{target_data}.pkl', 'rb') as f:
        target_val = pickle.load(f)
    with open(f'data_{dataset}/target_test_{target_data}.pkl', 'rb') as f:
        target_test = pickle.load(f)
        
    target_train = scaler.fit_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_val = scaler.transform(np.array(target_val).reshape(-1, 1)).flatten()
    target_test = scaler.transform(np.array(target_test).reshape(-1, 1)).flatten()
    target_train = torch.tensor(target_train, dtype=torch.float32)
    target_val = torch.tensor(target_val, dtype=torch.float32)
    target_test = torch.tensor(target_test, dtype=torch.float32)

    train_loader = DataLoader(list(zip(data_train_list, target_train)), batch_size=128, collate_fn=custom_collate)
    val_loader = DataLoader(list(zip(data_val_list, target_val)), batch_size=128, collate_fn=custom_collate)
    test_loader = DataLoader(list(zip(data_test_list, target_test)), batch_size=128, collate_fn=custom_collate)

    model = Net().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.MSELoss()

    early_stopping_patience = 30
    best_val_loss = float('inf')
    patience_counter = 0

    loss_train = []
    for epoch in range(100):
        model.train()
        for data, target in train_loader:
            data = data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            out = model(data)
            loss = criterion(out, target.view(-1, 1))
            loss.backward()
            optimizer.step()
            loss_train.append(loss.item())
        
        model.eval()
        val_loss = 0
        total_size = 0
        with torch.no_grad():
            for data, target in val_loader:
                data = data.to(device)
                target = target.to(device)
                out = model(data)
                loss = criterion(out, target.view(-1, 1))
                val_loss += loss.item() * data.size(0)
                total_size += data.size(0)
        val_loss /= total_size
        
        print(f'Epoch {epoch+1}, Validation Loss: {val_loss}')
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), f'data_{dataset}/model_{dataset}_sc.pth')
        else:
            patience_counter += 1
        if patience_counter >= early_stopping_patience:
            print(f'Early stopping at epoch {epoch+1}')
            break
    
    model.load_state_dict(torch.load(f'data_{dataset}/model_{dataset}_sc.pth'))
    model.eval()
    
    pred_train = []
    for data, target in train_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_train.append(out.cpu().numpy())
    pred_train = np.concatenate(pred_train)

    pred_test = []
    for data, target in test_loader:
        data = data.to(device)
        with torch.no_grad():
            out = model(data)
        pred_test.append(out.cpu().numpy())
    pred_test = np.concatenate(pred_test)

    pred_train = scaler.inverse_transform(pred_train)
    pred_test = scaler.inverse_transform(pred_test)
    target_train = scaler.inverse_transform(np.array(target_train).reshape(-1, 1)).flatten()
    target_test = scaler.inverse_transform(np.array(target_test).reshape(-1, 1)).flatten()

    print('R2 train:', metrics.r2_score(target_train, pred_train))
    print('R2 test:', metrics.r2_score(target_test, pred_test))
    
    n = 6000
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(range(0, n+1), range(0, n+1), c='black')
    plt.scatter(target_test, pred_test, c='green', s=5)
    plt.xlim(0, n)
    plt.ylim(0, n)
    ax.set_aspect('equal', adjustable='box')
    plt.xlabel("calculation")
    plt.ylabel("prediction")
    plt.show()
    fig.savefig(f'data_{dataset}/source_sc.pdf')
    print('======================================================')
# Out:
# Dataset :  AI+Human
# Epoch 1, Validation Loss: 0.3766291099770561
# Epoch 2, Validation Loss: 0.22324316057639745
# Epoch 3, Validation Loss: 0.14655164125611558
# Epoch 4, Validation Loss: 0.11628759208734853
# Epoch 5, Validation Loss: 0.09645685307141592
# Epoch 6, Validation Loss: 0.07337205249357358
# Epoch 7, Validation Loss: 0.06156240338810074
# Epoch 8, Validation Loss: 0.05389350092050137
# Epoch 9, Validation Loss: 0.0508824550700651
# Epoch 10, Validation Loss: 0.047011222655865215
# Epoch 11, Validation Loss: 0.04605260222962207
# Epoch 12, Validation Loss: 0.04036004518023914
# Epoch 13, Validation Loss: 0.03996741287550313
# Epoch 14, Validation Loss: 0.03996509079855238
# Epoch 15, Validation Loss: 0.03644494226611154
# Epoch 16, Validation Loss: 0.03325810269317504
# Epoch 17, Validation Loss: 0.03402756923306195
# Epoch 18, Validation Loss: 0.03171265946251658
# Epoch 19, Validation Loss: 0.032710927368821176
# Epoch 20, Validation Loss: 0.03214304337671088
# Epoch 21, Validation Loss: 0.03864384998736833
# Epoch 22, Validation Loss: 0.03349655336225366
# Epoch 23, Validation Loss: 0.03200346709379833
# Epoch 24, Validation Loss: 0.03390334250865681
# Epoch 25, Validation Loss: 0.028983199572726326
# Epoch 26, Validation Loss: 0.027597570442373466
# Epoch 27, Validation Loss: 0.026620506380501188
# Epoch 28, Validation Loss: 0.026812641342013683
# Epoch 29, Validation Loss: 0.02365848089668519
# Epoch 30, Validation Loss: 0.02488167264720867
# Epoch 31, Validation Loss: 0.02417285504074853
# Epoch 32, Validation Loss: 0.026046190701368144
# Epoch 33, Validation Loss: 0.023379509641141192
# Epoch 34, Validation Loss: 0.036047181463083895
# Epoch 35, Validation Loss: 0.03285771385345354
# Epoch 36, Validation Loss: 0.028674618314860227
# Epoch 37, Validation Loss: 0.027650971249356646
# Epoch 38, Validation Loss: 0.02671411788985289
# Epoch 39, Validation Loss: 0.023726660945655332
# Epoch 40, Validation Loss: 0.021727595250390766
# Epoch 41, Validation Loss: 0.021612970756728505
# Epoch 42, Validation Loss: 0.02298745637534111
# Epoch 43, Validation Loss: 0.024628664023429322
# Epoch 44, Validation Loss: 0.026326280891005426
# Epoch 45, Validation Loss: 0.02946376470369125
# Epoch 46, Validation Loss: 0.02962271401726315
# Epoch 47, Validation Loss: 0.02543611654012039
# Epoch 48, Validation Loss: 0.02180638255805905
# Epoch 49, Validation Loss: 0.021358263690597998
# Epoch 50, Validation Loss: 0.02145586774478807
# Epoch 51, Validation Loss: 0.02032166378954368
# Epoch 52, Validation Loss: 0.019442191475963492
# Epoch 53, Validation Loss: 0.020519953661342804
# Epoch 54, Validation Loss: 0.022254934791544344
# Epoch 55, Validation Loss: 0.020222420694338963
# Epoch 56, Validation Loss: 0.018287640005505285
# Epoch 57, Validation Loss: 0.018759014992704316
# Epoch 58, Validation Loss: 0.029678692269959107
# Epoch 59, Validation Loss: 0.020429959187880167
# Epoch 60, Validation Loss: 0.02150087203825822
# Epoch 61, Validation Loss: 0.021417983412294648
# Epoch 62, Validation Loss: 0.018262790134523338
# Epoch 63, Validation Loss: 0.021682812563161773
# Epoch 64, Validation Loss: 0.020903314233636287
# Epoch 65, Validation Loss: 0.02508743103940235
# Epoch 66, Validation Loss: 0.01852077396740384
# Epoch 67, Validation Loss: 0.01754763717698062
# Epoch 68, Validation Loss: 0.01763879897650976
# Epoch 69, Validation Loss: 0.017397715051599517
# Epoch 70, Validation Loss: 0.016991964364093004
# Epoch 71, Validation Loss: 0.01796846098644111
# Epoch 72, Validation Loss: 0.016586094547109832
# Epoch 73, Validation Loss: 0.016572438650109177
# Epoch 74, Validation Loss: 0.018290995168284276
# Epoch 75, Validation Loss: 0.017573478953259825
# Epoch 76, Validation Loss: 0.016199546907721088
# Epoch 77, Validation Loss: 0.01697239377464699
# Epoch 78, Validation Loss: 0.022263629239341446
# Epoch 79, Validation Loss: 0.024654781379635792
# Epoch 80, Validation Loss: 0.016908124720606
# Epoch 81, Validation Loss: 0.016528782609949215
# Epoch 82, Validation Loss: 0.01609344032164784
# Epoch 83, Validation Loss: 0.017426717088191563
# Epoch 84, Validation Loss: 0.0169991460762719
# Epoch 85, Validation Loss: 0.016494133239418715
# Epoch 86, Validation Loss: 0.018863784403440022
# Epoch 87, Validation Loss: 0.026988095904968916
# Epoch 88, Validation Loss: 0.021240256848775823
# Epoch 89, Validation Loss: 0.018880487582868897
# Epoch 90, Validation Loss: 0.018422330899884733
# Epoch 91, Validation Loss: 0.019040329065095413
# Epoch 92, Validation Loss: 0.02058742382362994
# Epoch 93, Validation Loss: 0.023638468801416734
# Epoch 94, Validation Loss: 0.020143280248101553
# Epoch 95, Validation Loss: 0.01990562673033122
# Epoch 96, Validation Loss: 0.017334491626796972
# Epoch 97, Validation Loss: 0.021148541843531148
# Epoch 98, Validation Loss: 0.017585253276777516
# Epoch 99, Validation Loss: 0.015425292710807718
# Epoch 100, Validation Loss: 0.01573677201315396
# R2 train: 0.9932953119277954
# R2 test: 0.9854251146316528
# ======================================================
# Dataset :  AI2+Human
# Epoch 1, Validation Loss: 0.2703573760550514
# Epoch 2, Validation Loss: 0.21102059477079138
# Epoch 3, Validation Loss: 0.12318069367184051
# Epoch 4, Validation Loss: 0.0974488556131836
# Epoch 5, Validation Loss: 0.12519091255127981
# Epoch 6, Validation Loss: 0.07999250418955517
# Epoch 7, Validation Loss: 0.06446665463461462
# Epoch 8, Validation Loss: 0.05476542452042377
# Epoch 9, Validation Loss: 0.052515058854546944
# Epoch 10, Validation Loss: 0.04678198537115674
# Epoch 11, Validation Loss: 0.04485979257324272
# Epoch 12, Validation Loss: 0.05051811471313883
# Epoch 13, Validation Loss: 0.04375490546040322
# Epoch 14, Validation Loss: 0.033536050443251766
# Epoch 15, Validation Loss: 0.03434240918756639
# Epoch 16, Validation Loss: 0.036947559762558084
# Epoch 17, Validation Loss: 0.032790626365451936
# Epoch 18, Validation Loss: 0.029997076281816304
# Epoch 19, Validation Loss: 0.02615072246149929
# Epoch 20, Validation Loss: 0.03349393253359257
# Epoch 21, Validation Loss: 0.036252853751474697
# Epoch 22, Validation Loss: 0.04225417952948642
# Epoch 23, Validation Loss: 0.04308099616096832
# Epoch 24, Validation Loss: 0.0250456945324252
# Epoch 25, Validation Loss: 0.023993001897957406
# Epoch 26, Validation Loss: 0.024285731732024026
# Epoch 27, Validation Loss: 0.021828444276702844
# Epoch 28, Validation Loss: 0.02289353827935599
# Epoch 29, Validation Loss: 0.03464784062629949
# Epoch 30, Validation Loss: 0.031029765196587494
# Epoch 31, Validation Loss: 0.03464136861020516
# Epoch 32, Validation Loss: 0.03886872542411172
# Epoch 33, Validation Loss: 0.03845768277226809
# Epoch 34, Validation Loss: 0.026849130335628853
# Epoch 35, Validation Loss: 0.03634146726749843
# Epoch 36, Validation Loss: 0.03104557190751519
# Epoch 37, Validation Loss: 0.031205798933300197
# Epoch 38, Validation Loss: 0.028019731842625267
# Epoch 39, Validation Loss: 0.02338055090540599
# Epoch 40, Validation Loss: 0.0229026042032415
# Epoch 41, Validation Loss: 0.023744316621484064
# Epoch 42, Validation Loss: 0.021617768037414508
# Epoch 43, Validation Loss: 0.021383326875084242
# Epoch 44, Validation Loss: 0.021211799173189456
# Epoch 45, Validation Loss: 0.021714815033402907
# Epoch 46, Validation Loss: 0.02563831103938595
# Epoch 47, Validation Loss: 0.02400897142502778
# Epoch 48, Validation Loss: 0.01633326210728241
# Epoch 49, Validation Loss: 0.01574224641686601
# Epoch 50, Validation Loss: 0.014388629471994168
# Epoch 51, Validation Loss: 0.014478719848986589
# Epoch 52, Validation Loss: 0.01416227635724824
# Epoch 53, Validation Loss: 0.015880959578931365
# Epoch 54, Validation Loss: 0.014032138575901116
# Epoch 55, Validation Loss: 0.01730261104732043
# Epoch 56, Validation Loss: 0.017787855951509994
# Epoch 57, Validation Loss: 0.014350234967653265
# Epoch 58, Validation Loss: 0.014248357437483997
# Epoch 59, Validation Loss: 0.013668043049138523
# Epoch 60, Validation Loss: 0.013032517286069275
# Epoch 61, Validation Loss: 0.013370653255839523
# Epoch 62, Validation Loss: 0.022155272729274273
# Epoch 63, Validation Loss: 0.013420468154171765
# Epoch 64, Validation Loss: 0.012370548138994776
# Epoch 65, Validation Loss: 0.01436295389737753
# Epoch 66, Validation Loss: 0.01391676589958972
# Epoch 67, Validation Loss: 0.012236982916269777
# Epoch 68, Validation Loss: 0.011814595872562889
# Epoch 69, Validation Loss: 0.014873568331346851
# Epoch 70, Validation Loss: 0.01203083128214057
# Epoch 71, Validation Loss: 0.011881560907991404
# Epoch 72, Validation Loss: 0.011455189841526539
# Epoch 73, Validation Loss: 0.017627775766956507
# Epoch 74, Validation Loss: 0.011245000983412964
# Epoch 75, Validation Loss: 0.011157872195363466
# Epoch 76, Validation Loss: 0.011410699204695226
# Epoch 77, Validation Loss: 0.01126582254229896
# Epoch 78, Validation Loss: 0.01077701206861176
# Epoch 79, Validation Loss: 0.011514622047318478
# Epoch 80, Validation Loss: 0.011391980771019251
# Epoch 81, Validation Loss: 0.011886164941030442
# Epoch 82, Validation Loss: 0.010743333724345775
# Epoch 83, Validation Loss: 0.012779632654658776
# Epoch 84, Validation Loss: 0.012677038512820942
# Epoch 85, Validation Loss: 0.011062482139513751
# Epoch 86, Validation Loss: 0.011337367422897099
# Epoch 87, Validation Loss: 0.012958342069034845
# Epoch 88, Validation Loss: 0.012913518385080794
# Epoch 89, Validation Loss: 0.012391296351575164
# Epoch 90, Validation Loss: 0.01391669905276137
# Epoch 91, Validation Loss: 0.013828611173408813
# Epoch 92, Validation Loss: 0.020833197878847767
# Epoch 93, Validation Loss: 0.011576434668732052
# Epoch 94, Validation Loss: 0.011732129449543747
# Epoch 95, Validation Loss: 0.010949648882080509
# Epoch 96, Validation Loss: 0.010278377694513221
# Epoch 97, Validation Loss: 0.010759838832306735
# Epoch 98, Validation Loss: 0.011756519982454739
# Epoch 99, Validation Loss: 0.010939255058435841
# Epoch 100, Validation Loss: 0.010705717535587826
# R2 train: 0.9952142238616943
# R2 test: 0.9896124601364136
# ======================================================
# Dataset :  Random+Human
# Epoch 1, Validation Loss: 0.29171290458763904
# Epoch 2, Validation Loss: 0.1969922133484246
# Epoch 3, Validation Loss: 0.13571030389385116
# Epoch 4, Validation Loss: 0.12030751184921874
# Epoch 5, Validation Loss: 0.08798744005058938
# Epoch 6, Validation Loss: 0.07658707921176774
# Epoch 7, Validation Loss: 0.06447392788959223
# Epoch 8, Validation Loss: 0.058025068997723604
# Epoch 9, Validation Loss: 0.053019242162472564
# Epoch 10, Validation Loss: 0.05129482604839239
# Epoch 11, Validation Loss: 0.05137496622317151
# Epoch 12, Validation Loss: 0.04362260185165119
# Epoch 13, Validation Loss: 0.04006204651166045
# Epoch 14, Validation Loss: 0.0391768798739965
# Epoch 15, Validation Loss: 0.03741713648773784
# Epoch 16, Validation Loss: 0.036889612266439324
# Epoch 17, Validation Loss: 0.034607793394724765
# Epoch 18, Validation Loss: 0.034910185340587846
# Epoch 19, Validation Loss: 0.03372728601215252
# Epoch 20, Validation Loss: 0.033775070940778765
# Epoch 21, Validation Loss: 0.033297851822202414
# Epoch 22, Validation Loss: 0.034571932307530306
# Epoch 23, Validation Loss: 0.031878917370502656
# Epoch 24, Validation Loss: 0.03154270666670281
# Epoch 25, Validation Loss: 0.028805708054249816
# Epoch 26, Validation Loss: 0.026716202531239425
# Epoch 27, Validation Loss: 0.02536066731889579
# Epoch 28, Validation Loss: 0.02551319535336352
# Epoch 29, Validation Loss: 0.02614596601153078
# Epoch 30, Validation Loss: 0.02523402509492163
# Epoch 31, Validation Loss: 0.02849099288845369
# Epoch 32, Validation Loss: 0.0236534598169937
# Epoch 33, Validation Loss: 0.030577105971472035
# Epoch 34, Validation Loss: 0.02802121242628808
# Epoch 35, Validation Loss: 0.04196185272159176
# Epoch 36, Validation Loss: 0.03425249508284392
# Epoch 37, Validation Loss: 0.024820162204519096
# Epoch 38, Validation Loss: 0.02230829340496187
# Epoch 39, Validation Loss: 0.023078566510897763
# Epoch 40, Validation Loss: 0.022630609796363707
# Epoch 41, Validation Loss: 0.02194097033592541
# Epoch 42, Validation Loss: 0.04622307309013185
# Epoch 43, Validation Loss: 0.020315242083570193
# Epoch 44, Validation Loss: 0.02176042207979395
# Epoch 45, Validation Loss: 0.021593466248808913
# Epoch 46, Validation Loss: 0.021238095232625993
# Epoch 47, Validation Loss: 0.028629077760319463
# Epoch 48, Validation Loss: 0.022235414005421495
# Epoch 49, Validation Loss: 0.022384219181216913
# Epoch 50, Validation Loss: 0.02203916860956156
# Epoch 51, Validation Loss: 0.027546411608515294
# Epoch 52, Validation Loss: 0.021887444509363165
# Epoch 53, Validation Loss: 0.02150327025523382
# Epoch 54, Validation Loss: 0.021117795145012365
# Epoch 55, Validation Loss: 0.019933527678068556
# Epoch 56, Validation Loss: 0.019685534043571727
# Epoch 57, Validation Loss: 0.018872360846843555
# Epoch 58, Validation Loss: 0.01910543491099802
# Epoch 59, Validation Loss: 0.020422026304450443
# Epoch 60, Validation Loss: 0.020805834885478033
# Epoch 61, Validation Loss: 0.019152673861407864
# Epoch 62, Validation Loss: 0.019031238326262082
# Epoch 63, Validation Loss: 0.0201368423803604
# Epoch 64, Validation Loss: 0.0188318139700017
# Epoch 65, Validation Loss: 0.02034182682903098
# Epoch 66, Validation Loss: 0.029447902990288346
# Epoch 67, Validation Loss: 0.02403139115110117
# Epoch 68, Validation Loss: 0.020742144385927606
# Epoch 69, Validation Loss: 0.019324014262193892
# Epoch 70, Validation Loss: 0.02067761142568297
# Epoch 71, Validation Loss: 0.019694937711934448
# Epoch 72, Validation Loss: 0.021430262177440103
# Epoch 73, Validation Loss: 0.01993735038402399
# Epoch 74, Validation Loss: 0.022440783873859876
# Epoch 75, Validation Loss: 0.027624819185856436
# Epoch 76, Validation Loss: 0.01884895868637301
# Epoch 77, Validation Loss: 0.02289590310027042
# Epoch 78, Validation Loss: 0.020606921282130868
# Epoch 79, Validation Loss: 0.018500809930112716
# Epoch 80, Validation Loss: 0.018387531937801307
# Epoch 81, Validation Loss: 0.018361909224156012
# Epoch 82, Validation Loss: 0.019142115731217175
# Epoch 83, Validation Loss: 0.01750421336845519
# Epoch 84, Validation Loss: 0.017422063740865353
# Epoch 85, Validation Loss: 0.01837665631596745
# Epoch 86, Validation Loss: 0.01805563334599346
# Epoch 87, Validation Loss: 0.018367561052570456
# Epoch 88, Validation Loss: 0.02902105908684094
# Epoch 89, Validation Loss: 0.017970894063556297
# Epoch 90, Validation Loss: 0.020447249198023116
# Epoch 91, Validation Loss: 0.020508305644022593
# Epoch 92, Validation Loss: 0.018041853055780425
# Epoch 93, Validation Loss: 0.021412725363536705
# Epoch 94, Validation Loss: 0.018145360163019732
# Epoch 95, Validation Loss: 0.02315146174547828
# Epoch 96, Validation Loss: 0.017140008530615435
# Epoch 97, Validation Loss: 0.023905260478488545
# Epoch 98, Validation Loss: 0.022193933016794606
# Epoch 99, Validation Loss: 0.032092994699676844
# Epoch 100, Validation Loss: 0.033111031020149145
# R2 train: 0.9932090044021606
# R2 test: 0.9834434986114502
# ======================================================
