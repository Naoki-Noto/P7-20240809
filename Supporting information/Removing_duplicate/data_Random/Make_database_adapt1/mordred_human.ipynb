# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from mordred import Calculator, descriptors

# %%
def remove_all_zero_col(data):
    data = data.copy()
    for col in data.columns:
        if (data[col] == 0).all():
            data.drop(col, axis=1, inplace=True)
    return data

# %%
data = pd.read_csv("source/Human_made_smiles_2.csv")
smiles = data['SMILES']
smiles
# Out:
# 0                                  CN(C)c1ccc(-c2ccon2)cc1
# 1                                  CN(C)c1ccc(-c2ccno2)cc1
# 2                                  CN(C)c1ccc(-c2cnoc2)cc1
# 3                                  CN(C)c1ccc(-c2ncco2)cc1
# 4                                  CN(C)c1ccc(-c2cocn2)cc1
#                                ...
# 25185    Fc1ccc2c(c1)c1cc(F)ccc1n2-c1ccc2c(c1)sc1cc(-c3...
# 25186    N#Cc1nc2c3cc(-c4ccc5c(c4)sc4cc(-n6c7ccc(F)cc7c...
# 25187    N#Cc1nc2c3ccc(-c4ccc5c(c4)sc4cc(-n6c7ccc(F)cc7...
# 25188    Fc1ccc2c(c1)c1cc(F)ccc1n2-c1ccc2c(c1)sc1cc(-c3...
# 25189    Fc1ccc2c(c1)c1cc(F)ccc1n2-c1ccc2c(c1)sc1cc(-c3...
# Name: SMILES, Length: 25190, dtype: object

# %%
data['Mol'] = data['SMILES'].apply(Chem.MolFromSmiles)
calc_mordred = Calculator(descriptors, ignore_3D=True)
desc_mordred = calc_mordred.pandas(data['Mol'])
mordred = desc_mordred.astype(str)
masks = mordred.apply(lambda d: d.str.contains('[a-zA-Z]' ,na=False))
mordred = mordred[~masks]
mordred = mordred.astype(float)

mordred
# Out:
#   6%|████▍                                                                        | 1436/25190 [00:42<15:45, 25.11it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▍                                                                        | 1439/25190 [00:42<24:09, 16.39it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▌                                                                        | 1493/25190 [00:45<27:19, 14.45it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1571/25190 [00:49<32:49, 11.99it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1576/25190 [00:49<33:03, 11.90it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1582/25190 [00:49<28:16, 13.91it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|████████████████████████████████████████████████████████████████████████████| 25190/25190 [25:41<00:00, 16.34it/s]
#              ABC      ABCGG  nAcid  nBase     SpAbs_A   SpMax_A  SpDiam_A  \
# 0      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 1      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 2      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 3      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 4      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# ...          ...        ...    ...    ...         ...       ...       ...
# 25185  56.863966  31.042341    0.0    0.0   93.317979  2.584707  4.996151
# 25186  65.106607  36.493532    0.0    0.0  107.074792  2.592711  5.171252
# 25187  65.106607  36.949974    0.0    0.0  107.075236  2.592758  5.171186
# 25188  51.954659  30.282662    0.0    0.0   84.920669  2.585699  5.001636
# 25189  58.904406  31.654585    0.0    0.0   96.375028  2.585549  5.076607
#
#            SpAD_A   SpMAD_A   LogEE_A  ...      SRW10      TSRW10  \
# 0       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 1       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 2       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 3       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 4       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# ...           ...       ...       ...  ...        ...         ...
# 25185   93.317979  1.372323  5.208501  ...  11.482909  127.440131
# 25186  107.074792  1.372754  5.347239  ...  11.686097  138.267977
# 25187  107.075236  1.372759  5.347239  ...  11.686097  138.267977
# 25188   84.920669  1.369688  5.119092  ...  11.412320  121.035798
# 25189   96.375028  1.376786  5.243605  ...  11.561706  129.719778
#
#                 MW       AMW    WPath   WPol  Zagreb1  Zagreb2   mZagreb1  \
# 0       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 1       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 2       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 3       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 4       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# ...            ...       ...      ...    ...      ...      ...        ...
# 25185   922.184802  9.410049  29030.0  134.0    410.0    513.0  15.833333
# 25186  1046.190950  9.686953  37127.0  162.0    474.0    599.0  19.000000
# 25187  1046.190950  9.686953  35783.0  162.0    474.0    599.0  19.000000
# 25188   845.158253  9.496160  20511.0  123.0    376.0    472.0  14.611111
# 25189   946.184802  9.461848  30355.0  142.0    428.0    539.0  16.055556
#
#         mZagreb2
# 0       3.138889
# 1       3.138889
# 2       3.138889
# 3       3.138889
# 4       3.138889
# ...          ...
# 25185  14.000000
# 25186  16.166667
# 25187  16.166667
# 25188  12.722222
# 25189  14.305556
#
# [25190 rows x 1613 columns]

# %%
mordred.to_csv('result/mordred_human.csv', index=False)
