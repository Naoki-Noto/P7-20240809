# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from mordred import Calculator, descriptors

# %%
def remove_all_zero_col(data):
    data = data.copy()
    for col in data.columns:
        if (data[col] == 0).all():
            data.drop(col, axis=1, inplace=True)
    return data

# %%
data = pd.read_csv("source/Human_made_smiles.csv")
smiles = data['SMILES']
smiles
# Out:
# 0                                  CN(C)c1ccc(-c2ccon2)cc1
# 1                                  CN(C)c1ccc(-c2ccno2)cc1
# 2                                  CN(C)c1ccc(-c2cnoc2)cc1
# 3                                  CN(C)c1ccc(-c2ncco2)cc1
# 4                                  CN(C)c1ccc(-c2cocn2)cc1
#                                ...
# 25345    Fc1ccc2c(c1)c1cc(F)ccc1n2-c1ccc2c(c1)sc1cc(-c3...
# 25346    N#Cc1nc2c3cc(-c4ccc5c(c4)sc4cc(-n6c7ccc(F)cc7c...
# 25347    N#Cc1nc2c3ccc(-c4ccc5c(c4)sc4cc(-n6c7ccc(F)cc7...
# 25348    Fc1ccc2c(c1)c1cc(F)ccc1n2-c1ccc2c(c1)sc1cc(-c3...
# 25349    Fc1ccc2c(c1)c1cc(F)ccc1n2-c1ccc2c(c1)sc1cc(-c3...
# Name: SMILES, Length: 25350, dtype: object

# %%
data['Mol'] = data['SMILES'].apply(Chem.MolFromSmiles)
calc_mordred = Calculator(descriptors, ignore_3D=True)
desc_mordred = calc_mordred.pandas(data['Mol'])
mordred = desc_mordred.astype(str)
masks = mordred.apply(lambda d: d.str.contains('[a-zA-Z]' ,na=False))
mordred = mordred[~masks]
mordred = mordred.astype(float)

mordred
# Out:
#   6%|████▎                                                                        | 1440/25350 [00:46<16:21, 24.36it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▍                                                                        | 1444/25350 [00:47<26:03, 15.29it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▌                                                                        | 1497/25350 [00:50<32:43, 12.15it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▌                                                                        | 1513/25350 [00:51<32:45, 12.13it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1572/25350 [00:54<20:03, 19.76it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1576/25350 [00:54<34:38, 11.44it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1580/25350 [00:55<36:04, 10.98it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#   6%|████▊                                                                        | 1583/25350 [00:55<38:07, 10.39it/s]
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\noton\miniconda3\envs\adapt1\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|████████████████████████████████████████████████████████████████████████████| 25350/25350 [26:53<00:00, 15.71it/s]
#              ABC      ABCGG  nAcid  nBase     SpAbs_A   SpMax_A  SpDiam_A  \
# 0      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 1      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 2      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 3      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# 4      10.744501   9.576492    0.0    0.0   18.067605  2.330714  4.622198
# ...          ...        ...    ...    ...         ...       ...       ...
# 25345  56.863966  31.042341    0.0    0.0   93.317979  2.584707  4.996151
# 25346  65.106607  36.493532    0.0    0.0  107.074792  2.592711  5.171252
# 25347  65.106607  36.949974    0.0    0.0  107.075236  2.592758  5.171186
# 25348  51.954659  30.282662    0.0    0.0   84.920669  2.585699  5.001636
# 25349  58.904406  31.654585    0.0    0.0   96.375028  2.585549  5.076607
#
#            SpAD_A   SpMAD_A   LogEE_A  ...      SRW10      TSRW10  \
# 0       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 1       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 2       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 3       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# 4       18.067605  1.290543  3.567018  ...   9.315691   58.493488
# ...           ...       ...       ...  ...        ...         ...
# 25345   93.317979  1.372323  5.208501  ...  11.482909  127.440131
# 25346  107.074792  1.372754  5.347239  ...  11.686097  138.267977
# 25347  107.075236  1.372759  5.347239  ...  11.686097  138.267977
# 25348   84.920669  1.369688  5.119092  ...  11.412320  121.035798
# 25349   96.375028  1.376786  5.243605  ...  11.561706  129.719778
#
#                 MW       AMW    WPath   WPol  Zagreb1  Zagreb2   mZagreb1  \
# 0       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 1       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 2       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 3       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# 4       188.094963  7.234422    317.0   17.0     70.0     80.0   4.444444
# ...            ...       ...      ...    ...      ...      ...        ...
# 25345   922.184802  9.410049  29030.0  134.0    410.0    513.0  15.833333
# 25346  1046.190950  9.686953  37127.0  162.0    474.0    599.0  19.000000
# 25347  1046.190950  9.686953  35783.0  162.0    474.0    599.0  19.000000
# 25348   845.158253  9.496160  20511.0  123.0    376.0    472.0  14.611111
# 25349   946.184802  9.461848  30355.0  142.0    428.0    539.0  16.055556
#
#         mZagreb2
# 0       3.138889
# 1       3.138889
# 2       3.138889
# 3       3.138889
# 4       3.138889
# ...          ...
# 25345  14.000000
# 25346  16.166667
# 25347  16.166667
# 25348  12.722222
# 25349  14.305556
#
# [25350 rows x 1613 columns]

# %%
mordred.to_csv('result/mordred_human.csv', index=False)
